# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib widget
import time
import itk
from itkwidgets import view
import pickle
import copy
import sys

# %% [markdown]
# ver 0.0

# %%
# def test_ge(num_id):
#     def index_matrix_generation():
#         index_matrix=np.zeros((720,720,768))
#         return index_matrix
#     index_matrix_tree=index_matrix_generation()


#     # In[3]:


#     def seed_generation():
#         #set starting seed at trechea
#         mu = 6 #
#         sigma = 2 
#         rand_pos = np.random.normal(mu, sigma, 3)
#         seed=np.array([int(rand_pos[0]),int(rand_pos[1])-20,80])
#         return seed
#     seed=seed_generation()


#     # ## Main branch parameter generation

#     # In[4]:


#     def parameter_generation(cl_mean,cl_sig,r_mean,r_sig,phi_min,phi_max,theta_min,theta_max,wall_mean,wall_sig):
#         cl=np.random.normal(cl_mean,cl_sig)
#         if cl<0:
#             cl=0
#         r=np.random.normal(r_mean,r_sig)
    
#         phi=np.random.randint(phi_min,phi_max)/180*np.pi
#         theta=np.random.randint(theta_min,theta_max)/180*np.pi
#         wall=np.random.normal(wall_mean,wall_sig)
#         return np.array([cl,r,phi,theta,wall])


#     # In[5]:


#     def normalized_parameter_generation(cl_mean,cl_sig,rn_mean,rn_sig,phi_min,phi_max,theta_min,theta_max,wall_mean,wall_sig,Trachea_r,limit=[0,0]):
#         cl=np.random.normal(cl_mean,cl_sig)
#         if cl<0:
#             cl=0
#     #     if cl>=1.5*limit[0]:
#     #         cl=1.5*limit[0]
#         r=np.random.normal(rn_mean,rn_sig/1.2)*Trachea_r
#         phi=np.random.randint(phi_min,phi_max)/180*np.pi
#         theta=np.random.randint(theta_min,theta_max)/180*np.pi
#         if limit[1] >0:
#             r=min(limit[1],r)
#         wall=np.random.normal(wall_mean,wall_sig)
#         return np.array([cl,r,phi,theta,wall])


#     # In[6]:


#     trachea=parameter_generation(109,14,23.9,2.9,175,185,18,20,2.6,0.24)## radius needed and centerline length needed
#     R=trachea[1]
#     rm=normalized_parameter_generation(25.5,2.5,0.84,0.13,265,275,30,35,2.3,0.33,R)
#     ru=normalized_parameter_generation(15,4,0.59,0.17,180,210,85,105,1.8,0.3,R,rm)
#     br=normalized_parameter_generation(29,3,0.653,0.11,175,195,30,45,1.82,0.25,R,rm)
#     r45=normalized_parameter_generation(19,4,0.38,0.09,180,225,60,90,1.6,0.15,R,br)
#     r6=normalized_parameter_generation(10,4,0.36,0.1,105,145,60,90,1.61,0.3,R,br)
#     rl7=normalized_parameter_generation(10.5,1.25,0.463,0.08,175,195,20,40,1.74,0.22,R,br)
#     r7=normalized_parameter_generation(16,5,0.27,0.06,-105,-30,30,45,1.45,0.17,R,rl7)
#     rl=normalized_parameter_generation(10,4,0.41,0.1,175,195,20,40,1.6,0.21,R,rl7)
#     r8=normalized_parameter_generation(12.5,1.5,0.296,0.073,195,255,45,60,1.51,0.17,R)
#     r910=normalized_parameter_generation(11,3.5,0.366,0.083,175,195,20,40,1.61,0.15,R,rl)
#     r9=normalized_parameter_generation(15,3.5,0.262,0.06,175,195,20,45,1.38,0.21,R,r910)
#     r10=normalized_parameter_generation(13,3.5,3.03,0.074,-30,30,0,45,1.45,0.16,R,r910)
#     r1=normalized_parameter_generation(13,3.5,0.33,0.06,-90,180,135,180,1.5,0.22,R,ru)
#     r2=normalized_parameter_generation(11,3,0.31,0.061,90,150,75,100,1.48,0.16,R,ru)
#     r3=normalized_parameter_generation(12,3.75,0.35,0.096,225,300,80,120,1.61,0.18,R,ru)
#     r4=normalized_parameter_generation(12.5,4,0.27,0.07,150,180,60,90,1.4,0.16,R,r45)
#     r5=normalized_parameter_generation(14,4,0.29,0.06,195,225,60,90,1.47,0.17,R,r45)

#     lm=normalized_parameter_generation(50,5,0.7,0.11,-15,5,30,35,2.06,0.34,R)
#     lu=normalized_parameter_generation(13,3,0.58,0.18,-45,0,85,105,1.92,0.3,R,lm)
#     ll6=normalized_parameter_generation(12.5,2.5,0.6,0.13,-15,5,30,45,1.97,0.32,R,lm)
#     l6=normalized_parameter_generation(10,2.8,0.41,0.15,55,105,50,90,1.71,0.22,R,ll6)
#     ll=normalized_parameter_generation(17,4,0.47,0.1,-15,5,30,45,1.76,0.15,R,ll6)
#     l8=normalized_parameter_generation(12.5,4,0.32,0.07,-75,5,45,60,1.57,0.15,R,ll)
#     l910=normalized_parameter_generation(10,3,0.42,0.1,-25,5,15,45,1.66,0.15,R,ll)
#     l9=normalized_parameter_generation(15,4.75,0.3,0.075,-35,0,20,45,1.48,0.21,R,l910)#cl=15
#     l10=normalized_parameter_generation(15,4.75,0.32,0.075,5,25,20,45,1.5,0.17,R,l910)#cl=15
#     l123=normalized_parameter_generation(11.5,3,0.454,0.125,-90,90,160,180,1.75,0.19,R,lu)
#     l12=normalized_parameter_generation(6,2.5,0.33,0.1,120,240,120,180,1.56,0.37,R,l123)
#     l1=normalized_parameter_generation(13,3.5,0.263,0.08,90,150,150,180,13.8,0.188,R,l12)
#     l2=normalized_parameter_generation(12.5,3,0.225,0.06,150,210,150,180,1.27,0.24,R,l12)
#     l3=normalized_parameter_generation(10,3,0.33,0.09,-60,60,120,150,1.57,0.175,R,l123)
#     l45=normalized_parameter_generation(14,5,0.40,0.1,-15,30,60,75,1.62,0.41,R,lu,)
#     l4=normalized_parameter_generation(12.5,5,0.264,0.05,-15,30,60,75,1.36,0.16,R,l45)
#     l5=normalized_parameter_generation(12.5,3.5,0.26,0.06,15,30,45,60,1.35,0.16,R,l45)


#     # ## One-D Tree generation

#     # In[7]:


#     def main_branch_generation(seed,index_matrix,branch,base=[0,0,0,0],label=60,vanish=1,bifurcate=1):
#         length=int(branch[0]*2)
#         phi=branch[2]
#         theta=branch[3]
#         base_r=int(base[1])
#         x=np.zeros((length))
#         y=np.zeros((length))
#         z=np.zeros((length))
#         x1=x
#         y1=y
#         z1=z
#         line=np.zeros((length))
#         line1=line
#         prob_v=np.random.binomial(1,vanish,1)[0]
#         prob_b=np.random.binomial(1,bifurcate,1)[0]
#         for i in range (0,length):
#             x[i]=int((base_r+i)*np.sin(theta)*np.cos(phi))+seed[0]
#             y[i]=int((base_r+i)*np.sin(theta)*np.sin(phi))+seed[1]
#             z[i]=int((base_r+i)*np.cos(theta))+seed[2]
#             line[i]=label
#             index_matrix[int(x[i])+360,int(y[i])+360,int(z[i])]=line[i]
#             if prob_v==0:
#                 index_matrix[int(x[i])+360,int(y[i])+360,int(z[i])]=0
#         end=length-1
#     #     end=np.array([x[end],y[end],z[end]])
#     #     if prob_v==0:
#     #         end=seed
#     #     if prob_b==0:
#     #         theta1=theta+np.random.randint(15,30)/180*np.pi
#     #         for j in range (0,length):
#     #             x1[j]=int((base_r+j)*np.sin(theta1)*np.cos(phi))+seed[0]
#     #             y1[j]=int((base_r+j)*np.sin(theta1)*np.sin(phi))+seed[1]
#     #             z1[j]=int((base_r+j)*np.cos(theta1))+seed[2]
#     #             line1[j]=label
#     #             index_matrix[int(x1[j])+360,int(y1[j])+360,int(z1[j])]=line1[j]
#     #         x=np.hstack((x,x1))
#     #         y=np.hstack((y,y1))
#     #         z=np.hstack((z,z1))
#         info=np.array([(x[0],y[0],z[0]),(x[end],y[end],z[end])])
#         return index_matrix,info


#     # In[8]:


#     def s_branch_generation (index_matrix,f_branch,seed,label=100):
#         length_factor=np.random.normal(7,1,2)/10
#         radius_factor=np.random.normal(6.5,0.8,2)/10
#     #     radius_factor=np.array([0.5,0.5])
#         theta_1=f_branch[3]+np.random.randint(5,22)/180*np.pi
#         theta_2=f_branch[3]-np.random.randint(5,22)/180*np.pi
#         phi_1=np.random.randint(15,20)/180+f_branch[2]
#         phi_2=f_branch[2]-np.random.randint(10,20)/180
#         length_1=int(length_factor[0]*f_branch[0]*2)
#         length_2=int(length_factor[1]*f_branch[0]*2)

#         x=np.zeros((length_1))
#         y=np.zeros((length_1))
#         z=np.zeros((length_1))
#         x1=np.zeros((length_2))
#         y1=np.zeros((length_2))
#         z1=np.zeros((length_2))
#         for i in range (0,length_1):
#             x[i]=int((f_branch[1]+i)*np.sin(theta_1)*np.cos(phi_1))+seed[1,0]
#             y[i]=int((f_branch[1]+i)*np.sin(theta_1)*np.sin(phi_1))+seed[1,1]
#             z[i]=int((f_branch[1]+i)*np.cos(theta_1))+seed[1,2]

#             index_matrix[int(x[i])+360,int(y[i])+360,int(z[i])]=label

#         l=len(x)-1
#         s_branch=[(x[0],y[0],z[0]),(x[l],y[l],z[l])]



#         for j in range (0,length_2):
#             x1[j]=int((f_branch[1]+j)*np.sin(theta_2)*np.cos(phi_2))+seed[1,0]
#             y1[j]=int((f_branch[1]+j)*np.sin(theta_2)*np.sin(phi_2))+seed[1,1]
#             z1[j]=int((f_branch[1]+j)*np.cos(theta_2))+seed[1,2]

#             index_matrix[int(x1[j])+360,int(y1[j])+360,int(z1[j])]=label
#     #         index_matrix1[int(x1[j])+360,int(y1[j])+360,int(z1[j])]=label
#         l1=length_2-1
#         s1_branch=[(x1[0],y1[0],z1[0]),(x1[l1],y1[l1],z1[l1])]
#     #     x=np.hstack((x,x1))
#     #     y=np.hstack((y,y1))
#     #     z=np.hstack((z,z1))
#         radius=radius_factor*f_branch[1]
#     #     print (s1_branch)

#         ends=np.array([(length_1,radius[0],phi_1,theta_1,x[0],y[0],z[0],x[l],y[l],z[l]),(length_2,radius[1],phi_2,theta_2,x1[0],y1[0],z1[0],x1[l1],y1[l1],z1[l1])])
#         return index_matrix,ends


#     # In[9]:


#     def ss_branch_generation0 (index_matrix,f_branch,label=60):
#         length_factor=np.random.normal(7.5,0.3,2)/10
#         radius_factor=np.random.normal(6.5,0.8,2)/10

#     #     radius_factor=np.array([0.5,0.5])
#         theta_1=f_branch[3]+np.random.randint(5,22)/180*np.pi
#         theta_2=f_branch[3]-np.random.randint(5,22)/180*np.pi
#         phi_1=np.random.randint(15,20)/180+f_branch[2]
#         phi_2=f_branch[2]-np.random.randint(10,20)/180
#         length_1=int(length_factor[0]*f_branch[0]*2)
#         if length_1<1:
#             length_1=2
#         length_2=int(length_factor[1]*f_branch[0]*2)
#         if length_2<1:
#             length_2=2
#     #     print (length_1,length_2)
#         x=np.zeros((length_1))
#         y=np.zeros((length_1))
#         z=np.zeros((length_1))
#         x1=np.zeros((length_2))
#         y1=np.zeros((length_2))
#         z1=np.zeros((length_2))
#         for i in range (0,length_1):
#             x[i]=int((f_branch[1]+i)*np.sin(theta_1)*np.cos(phi_1))+f_branch[7]
#             y[i]=int((f_branch[1]+i)*np.sin(theta_1)*np.sin(phi_1))+f_branch[8]
#             z[i]=int((f_branch[1]+i)*np.cos(theta_1))+f_branch[9]

#             index_matrix[int(x[i])+360,int(y[i])+360,int(z[i])]=label

#         l=length_1-1
#         s_branch=[(x[0],y[0],z[0]),(x[l],y[l],z[l])]



#         for j in range (0,length_2):
#             x1[j]=int((f_branch[1]+j)*np.sin(theta_2)*np.cos(phi_2))+f_branch[7]
#             y1[j]=int((f_branch[1]+j)*np.sin(theta_2)*np.sin(phi_2))+f_branch[8]
#             z1[j]=int((f_branch[1]+j)*np.cos(theta_2))+f_branch[9]

#             index_matrix[int(x1[j])+360,int(y1[j])+360,int(z1[j])]=label

#         l1=length_2-1
#         s1_branch=[(x1[0],y1[0],z1[0]),(x1[l1],y1[l1],z1[l1])]
#     #     x=np.hstack((x,x1))
#     #     y=np.hstack((y,y1))
#     #     z=np.hstack((z,z1))
#         radius=radius_factor*f_branch[1]
#     #     print (s1_branch)
#     #     print (radius)
#         ends=np.array([(length_1,radius[0],phi_1,theta_1,x[0],y[0],z[0],x[l],y[l],z[l]),(length_2,radius[1],phi_2,theta_2,x1[0],y1[0],z1[0],x1[l1],y1[l1],z1[l1])])
#         return index_matrix,ends

#     def ss_branch_generation(index_matrix,ends):
#         f_branch_0=ends[0]
#     #     print(f_branch_0)
#         f_branch_1=ends[1]
#     #     print(f_branch_1)
#         index_matrix,ends1=ss_branch_generation0(index_matrix,f_branch_0)
#         index_matrix,ends2=ss_branch_generation0(index_matrix,f_branch_1)
#         ends=np.vstack((ends1,ends2))

#         return index_matrix,ends



#     # In[10]:


#     index_matrix_tree,trachea_i=main_branch_generation(seed,index_matrix_tree,trachea)
#     #rmb
#     index_matrix_tree,rm_i=main_branch_generation(trachea_i[1],index_matrix_tree,rm,trachea)
#     #rul
#     index_matrix_tree,ru_i=main_branch_generation(rm_i[1],index_matrix_tree,ru,rm)
#     #bronlnt
#     index_matrix_tree,br_i=main_branch_generation(rm_i[1],index_matrix_tree,br,rm)
#     #rb4+5
#     index_matrix_tree,r45_i=main_branch_generation(br_i[1],index_matrix_tree,r45,br)
#     #rb6
#     index_matrix_tree,r6_i=main_branch_generation(br_i[1],index_matrix_tree,r6,br)
#     #rll7
#     index_matrix_tree,rl7_i=main_branch_generation(br_i[1],index_matrix_tree,rl7,br)
#     #rb7(future needs a vanish factor)
#     index_matrix_tree,r7_i=main_branch_generation(rl7_i[1],index_matrix_tree,r7,rl7)
#     #rll
#     index_matrix_tree,rl_i=main_branch_generation(rl7_i[1],index_matrix_tree,rl7)
#     #rb8(needs bifurcation factor)
#     index_matrix_tree,r8_i=main_branch_generation(rl_i[1],index_matrix_tree,r8,rl)
#     #rb9+10(needs a vanish factor)
#     index_matrix_tree,r910_i=main_branch_generation(rl_i[1],index_matrix_tree,r910,rl)
#     #rb9
#     index_matrix_tree,r9_i=main_branch_generation(r910_i[1],index_matrix_tree,r9,r910)
#     #rb10
#     index_matrix_tree,r10_i=main_branch_generation(r910_i[1],index_matrix_tree,r10,r910)
#     #rb1
#     index_matrix_tree,r1_i=main_branch_generation(ru_i[1],index_matrix_tree,r1,ru)
#     #rb2
#     index_matrix_tree,r2_i=main_branch_generation(ru_i[1],index_matrix_tree,r2,ru)
#     #rb3
#     index_matrix_tree,r3_i=main_branch_generation(ru_i[1],index_matrix_tree,r3,ru)
#     #rb4
#     index_matrix_tree,r4_i=main_branch_generation(r45_i[1],index_matrix_tree,r4,r45)
#     #rb5
#     index_matrix_tree,r5_i=main_branch_generation(r45_i[1],index_matrix_tree,r5,r45)
#     #lmb
#     index_matrix_tree,lm_i=main_branch_generation(trachea_i[1],index_matrix_tree,lm,trachea)
#     #lul
#     index_matrix_tree,lu_i=main_branch_generation(lm_i[1],index_matrix_tree,lu,lm)
#     #llb6
#     index_matrix_tree,ll6_i=main_branch_generation(lm_i[1],index_matrix_tree,ll6,lm)
#     #lb6
#     index_matrix_tree,l6_i=main_branch_generation(ll6_i[1],index_matrix_tree,l6,ll6)
#     #llb
#     index_matrix_tree,ll_i=main_branch_generation(ll6_i[1],index_matrix_tree,ll,ll6)
#     #lb8
#     index_matrix_tree,l8_i=main_branch_generation(ll_i[1],index_matrix_tree,l8,ll)
#     #lb9+10
#     index_matrix_tree,l910_i=main_branch_generation(ll_i[1],index_matrix_tree,l910,ll)
#     #lb9
#     index_matrix_tree,l9_i=main_branch_generation(l910_i[1],index_matrix_tree,l9,l910)
#     #lb10
#     index_matrix_tree,l10_i=main_branch_generation(l910_i[1],index_matrix_tree,l10,l910)
#     #lb1+2+3
#     index_matrix_tree,l123_i=main_branch_generation(lu_i[1],index_matrix_tree,l123,lu)
#     #lb1+2
#     index_matrix_tree,l12_i=main_branch_generation(l123_i[1],index_matrix_tree,l12,l123)
#     #lb3
#     index_matrix_tree,l3_i=main_branch_generation(l123_i[1],index_matrix_tree,l3,l123)
#     #lb1
#     index_matrix_tree,l1_i=main_branch_generation(l12_i[1],index_matrix_tree,l1,l12)
#     #lb2
#     index_matrix_tree,l2_i=main_branch_generation(l12_i[1],index_matrix_tree,l2,l12)
#     #lb4+5
#     index_matrix_tree,l45_i=main_branch_generation(lu_i[1],index_matrix_tree,l45,lu)
#     #lb4
#     index_matrix_tree,l4_i=main_branch_generation(l45_i[1],index_matrix_tree,l4,l45)
#     #lb5
#     index_matrix_tree,l5_i=main_branch_generation(l45_i[1],index_matrix_tree,l5,l45)    


#     # In[11]:


#     index_matrix_tree,sr1=s_branch_generation(index_matrix_tree,r1,r1_i)
#     index_matrix_tree,sr2=s_branch_generation(index_matrix_tree,r2,r2_i)
#     index_matrix_tree,sr3=s_branch_generation(index_matrix_tree,r3,r3_i)
#     index_matrix_tree,sr4=s_branch_generation(index_matrix_tree,r4,r4_i)
#     index_matrix_tree,sr5=s_branch_generation(index_matrix_tree,r5,r5_i)
#     index_matrix_tree,sr6=s_branch_generation(index_matrix_tree,r6,r6_i)
#     index_matrix_tree,sr7=s_branch_generation(index_matrix_tree,r7,r7_i)
#     index_matrix_tree,sr8=s_branch_generation(index_matrix_tree,r8,r8_i)
#     index_matrix_tree,sr9=s_branch_generation(index_matrix_tree,r9,r9_i)
#     index_matrix_tree,sr10=s_branch_generation(index_matrix_tree,r10,r10_i)
#     index_matrix_tree,sl1=s_branch_generation(index_matrix_tree,l1,l1_i)
#     index_matrix_tree,sl2=s_branch_generation(index_matrix_tree,l2,l2_i)
#     index_matrix_tree,sl3=s_branch_generation(index_matrix_tree,l3,l3_i)
#     index_matrix_tree,sl4=s_branch_generation(index_matrix_tree,l4,l4_i)
#     index_matrix_tree,sl5=s_branch_generation(index_matrix_tree,l5,l5_i)
#     index_matrix_tree,sl6=s_branch_generation(index_matrix_tree,l6,l6_i)
#     index_matrix_tree,sl8=s_branch_generation(index_matrix_tree,l8,l8_i)
#     index_matrix_tree,sl9=s_branch_generation(index_matrix_tree,l9,l9_i)
#     index_matrix_tree,sl10=s_branch_generation(index_matrix_tree,l10,l10_i)


#     # In[12]:


#     index_matrix_tree,ssr1=ss_branch_generation(index_matrix_tree,sr1)
#     index_matrix_tree,ssr2=ss_branch_generation(index_matrix_tree,sr2)
#     index_matrix_tree,ssr3=ss_branch_generation(index_matrix_tree,sr3)
#     index_matrix_tree,ssr4=ss_branch_generation(index_matrix_tree,sr4)
#     index_matrix_tree,ssr5=ss_branch_generation(index_matrix_tree,sr5)
#     index_matrix_tree,ssr6=ss_branch_generation(index_matrix_tree,sr6)
#     index_matrix_tree,ssr7=ss_branch_generation(index_matrix_tree,sr7)
#     index_matrix_tree,ssr8=ss_branch_generation(index_matrix_tree,sr8)
#     index_matrix_tree,ssr9=ss_branch_generation(index_matrix_tree,sr9)
#     index_matrix_tree,ssr10=ss_branch_generation(index_matrix_tree,sr10)
#     index_matrix_tree,ssl1=ss_branch_generation(index_matrix_tree,sl1)
#     index_matrix_tree,ssl2=ss_branch_generation(index_matrix_tree,sl2)
#     index_matrix_tree,ssl3=ss_branch_generation(index_matrix_tree,sl3)
#     index_matrix_tree,ssl4=ss_branch_generation(index_matrix_tree,sl4)
#     index_matrix_tree,ssl5=ss_branch_generation(index_matrix_tree,sl5)
#     index_matrix_tree,ssl6=ss_branch_generation(index_matrix_tree,sl6)
#     index_matrix_tree,ssl8=ss_branch_generation(index_matrix_tree,sl8)
#     index_matrix_tree,ssl9=ss_branch_generation(index_matrix_tree,sl9)
#     index_matrix_tree,ssl10=ss_branch_generation(index_matrix_tree,sl10)



#     # In[13]:


# #     index_matrix1=np.copy(index_matrix)



#     # ## Airway Modeling

#     # In[14]:
# #     matrix0=index_matrix_generation()
# #     matrix1=index_matrix_generation()

#     def airway_modeling(index_matrix,info,branch,num_id=60):
#     #     start=time.time()
#         P=info[0]+[360,360,0]
#         Q=info[1]+[360,360,0]
#         AB = Q - P;
#         temp = AB / np.dot(AB,AB);
#         r=branch[1]
#         ri=branch[1]-2*branch[4]
#         lmin=int(min(P[0],Q[0])-1.2*int(r))
#         lmax=int(max(P[0],Q[0])+1.2*int(r))
#         wmin=int(min(P[1],Q[1])-1.2*int(r))
#         wmax=int(max(P[1],Q[1])+1.2*int(r))
#         hmin=int(min(P[2],Q[2])-1*int(r))
#         if hmin<0:
#             hmin=0
#         hmax=int(max(P[2],Q[2])+1*int(r)+1)

#         x_range = np.sort(np.array([P[0], Q[0]]));
#         y_range = np.sort(np.array([P[1], Q[1]]));
#         z_range = np.sort(np.array([P[2], Q[2]]));
#         #for any point on line x^2+y^2+z^2=<r^2
#         for i in range(lmin,lmax):       
#             for j in range (wmin,wmax):
#                 for k in range(hmin,hmax):
#                     p = np.array([i, j, k])
#                     AP = p - P;
#                     BP = p - Q
#                     proj_point = P + np.dot(AP,AB) * temp;
#                     distance_s = (proj_point[0] - p[0])**2 + (proj_point[1] - p[1])**2 + (proj_point[2] - p[2])**2;
#                     distance_1_s = (P[0] - p[0])**2 + (P[1] - p[1])**2 + (P[2] - p[2])**2;
#                     distance_2_s = (Q[0] - p[0])**2 + (Q[1] - p[1])**2 + (Q[2] - p[2])**2;

#                     if distance_s <=r*r and index_matrix[i,j,k]==0 and (x_range[0] <= proj_point[0] and proj_point[0] <= x_range[1]) and (
#                                 y_range[0] <= proj_point[1] and proj_point[1] <= y_range[1]) and (
#                                         z_range[0] <= proj_point[2] and proj_point[2] <= z_range[1]) or distance_1_s<=r*r or distance_2_s<=r*r:
#                         if index_matrix[i,j,k]==0:


#                             index_matrix[i,j,k]=num_id
#                     if distance_s <=ri*ri and (x_range[0] <= proj_point[0] and proj_point[0] <= x_range[1]) and (
#                                 y_range[0] <= proj_point[1] and proj_point[1] <= y_range[1]) and (
#                                         z_range[0] <= proj_point[2] and proj_point[2] <= z_range[1]) or distance_1_s<=ri*ri or distance_2_s<=ri*ri:
#                         index_matrix[i,j,k]=255


#     #     end=time.time()
#     #     print (end-start,"s")
#         return index_matrix#,xx,yy,zz


#     # In[15]:


#     #np.array([(length_1,radius[0],phi_1,theta_1,x[0],y[0],z[0],x[l],y[l],z[l]),(length_2,radius[1],phi_2,theta_2,x1[0],y1[0],z1[0],x1[l1],y1[l1],z1[l1])])
#     def s_airway_modeling0(index_matrix,s_branch,num_id=100):
#     #     start=time.time()
#         P=np.array(s_branch)[4:7]+[360,360,0]
#         Q=np.array(s_branch)[7:10]+[360,360,0]
#         AB = Q - P;
#         temp = AB / np.dot(AB,AB);
#         r=s_branch[1]
#         ri=0.6*r


#         lmin=int(min(P[0],Q[0])-1.2*int(r))
#         lmax=int(max(P[0],Q[0])+1.2*int(r))
#         wmin=int(min(P[1],Q[1])-1.2*int(r))
#         wmax=int(max(P[1],Q[1])+1.2*int(r))
#         hmin=int(min(P[2],Q[2])-1*int(r))
#         if hmin<0:
#             hmin=0
#         hmax=int(max(P[2],Q[2])+1*int(r)+1)

#         x_range = np.sort(np.array([P[0], Q[0]]));
#         y_range = np.sort(np.array([P[1], Q[1]]));
#         z_range = np.sort(np.array([P[2], Q[2]]));
#         #for any point on line x^2+y^2+z^2=<r^2
#         for i in range(lmin,lmax):       
#             for j in range (wmin,wmax):
#                 for k in range(hmin,hmax):
#                     p = np.array([i, j, k])
#                     AP = p - P;
#                     BP = p - Q
#                     proj_point = P + np.dot(AP,AB) * temp;
#                     distance_s = (proj_point[0] - p[0])**2 + (proj_point[1] - p[1])**2 + (proj_point[2] - p[2])**2;
#                     distance_1_s = (P[0] - p[0])**2 + (P[1] - p[1])**2 + (P[2] - p[2])**2;
#                     distance_2_s = (Q[0] - p[0])**2 + (Q[1] - p[1])**2 + (Q[2] - p[2])**2;

#     #                 if distance_s <=r*r or distance_t1<=r*r or distance_t2<=r*r and index_matrix[i,k,k]==0:
#                     if distance_s <=r*r and index_matrix[i,j,k]==0 and (x_range[0] <= proj_point[0] and proj_point[0] <= x_range[1]) and (
#                                 y_range[0] <= proj_point[1] and proj_point[1] <= y_range[1]) and (
#                                         z_range[0] <= proj_point[2] and proj_point[2] <= z_range[1]) or distance_1_s<=r*r or distance_2_s<=r*r:
#                         if index_matrix[i,k,k]==0:


#                             index_matrix[i,j,k]=num_id

#                     if distance_s <=ri*ri and (x_range[0] <= proj_point[0] and proj_point[0] <= x_range[1]) and (
#                                 y_range[0] <= proj_point[1] and proj_point[1] <= y_range[1]) and (
#                                         z_range[0] <= proj_point[2] and proj_point[2] <= z_range[1]) or distance_1_s<=ri*ri or distance_2_s<=ri*ri:
#                         index_matrix[i,j,k]=255
#     #     end=time.time()
#     #     print (end-start,"s")
#         return index_matrix#,xx,yy,zz

#     def s_airway_modeling(index_matrix,s_branch):
#         index_matrix=s_airway_modeling0(index_matrix,s_branch[0])
#         index_matrix=s_airway_modeling0(index_matrix,s_branch[1])
#         return index_matrix


#     # In[16]:


#     def ss_airway_modeling(index_matrix,ss_branch):
#         for i in range(0,4):
#             index_matrix=s_airway_modeling0(index_matrix,ss_branch[i])
#         return index_matrix


#     # ## Generating testing image

#     # In[17]:


#     def generating_test_image(index_matrix):
#         start=time.time()
#         print ("generating main branch")
#         index_matrix=airway_modeling(index_matrix,trachea_i,trachea)
#         index_matrix=airway_modeling(index_matrix,rm_i,rm)
#         index_matrix=airway_modeling(index_matrix,ru_i,ru)
#         index_matrix=airway_modeling(index_matrix,br_i,br)
#         index_matrix=airway_modeling(index_matrix,r45_i,r45)
#         index_matrix=airway_modeling(index_matrix,r6_i,r6)
#         index_matrix=airway_modeling(index_matrix,rl7_i,rl7)
#         index_matrix=airway_modeling(index_matrix,rl_i,rl)
#         index_matrix=airway_modeling(index_matrix,r910_i,r910)
#         index_matrix=airway_modeling(index_matrix,r8_i,r8)
#         index_matrix=airway_modeling(index_matrix,r9_i,r9)
#         index_matrix=airway_modeling(index_matrix,r10_i,r10)
#         index_matrix=airway_modeling(index_matrix,r4_i,r4)
#         index_matrix=airway_modeling(index_matrix,r5_i,r5)
#         index_matrix=airway_modeling(index_matrix,r7_i,r7)
#         index_matrix=airway_modeling(index_matrix,r1_i,r8)
#         index_matrix=airway_modeling(index_matrix,r2_i,r2)
#         index_matrix=airway_modeling(index_matrix,r3_i,r3)
#         index_matrix=airway_modeling(index_matrix,lm_i,lm)
#         index_matrix=airway_modeling(index_matrix,ll6_i,ll6)
#         index_matrix=airway_modeling(index_matrix,l6_i,l6)
#         index_matrix=airway_modeling(index_matrix,ll_i,ll)
#         index_matrix=airway_modeling(index_matrix,l8_i,l8)
#         index_matrix=airway_modeling(index_matrix,l910_i,l910)
#         index_matrix=airway_modeling(index_matrix,lu_i,lu)
#         index_matrix=airway_modeling(index_matrix,l123_i,l123)
#         index_matrix=airway_modeling(index_matrix,l12_i,l12)
#         index_matrix=airway_modeling(index_matrix,l1_i,l1)
#         index_matrix=airway_modeling(index_matrix,l2_i,l2)
#         index_matrix=airway_modeling(index_matrix,l3_i,l3)
#         index_matrix=airway_modeling(index_matrix,l45_i,l45)
#         index_matrix=airway_modeling(index_matrix,l4_i,l4)
#         index_matrix=airway_modeling(index_matrix,l5_i,l5)
#         index_matrix=airway_modeling(index_matrix,l9_i,l9)
#         index_matrix=airway_modeling(index_matrix,l10_i,l10)

#         print ("generating son branch")
#         index_matrix=s_airway_modeling(index_matrix,sr1)
#         index_matrix=s_airway_modeling(index_matrix,sr2)
#         index_matrix=s_airway_modeling(index_matrix,sr3)
#         index_matrix=s_airway_modeling(index_matrix,sr4)
#         index_matrix=s_airway_modeling(index_matrix,sr5)
#         index_matrix=s_airway_modeling(index_matrix,sr6)
#         index_matrix=s_airway_modeling(index_matrix,sr7)
#         index_matrix=s_airway_modeling(index_matrix,sr8)
#         index_matrix=s_airway_modeling(index_matrix,sr9)
#         index_matrix=s_airway_modeling(index_matrix,sr10)
#         index_matrix=s_airway_modeling(index_matrix,sl1)
#         index_matrix=s_airway_modeling(index_matrix,sl2)
#         index_matrix=s_airway_modeling(index_matrix,sl3)
#         index_matrix=s_airway_modeling(index_matrix,sl4)
#         index_matrix=s_airway_modeling(index_matrix,sl5)
#         index_matrix=s_airway_modeling(index_matrix,sl6)
#         index_matrix=s_airway_modeling(index_matrix,sl8)
#         index_matrix=s_airway_modeling(index_matrix,sl9)
#         index_matrix=s_airway_modeling(index_matrix,sl10)

#         print("generating grandson branch")
#         index_matrix=ss_airway_modeling(index_matrix,ssr1)
#         index_matrix=ss_airway_modeling(index_matrix,ssr2)
#         index_matrix=ss_airway_modeling(index_matrix,ssr3)
#         index_matrix=ss_airway_modeling(index_matrix,ssr4)
#         index_matrix=ss_airway_modeling(index_matrix,ssr5)
#         index_matrix=ss_airway_modeling(index_matrix,ssr6)
#         index_matrix=ss_airway_modeling(index_matrix,ssr7)
#         index_matrix=ss_airway_modeling(index_matrix,ssr8)
#         index_matrix=ss_airway_modeling(index_matrix,ssr9)
#         index_matrix=ss_airway_modeling(index_matrix,ssr10)
#         index_matrix=ss_airway_modeling(index_matrix,ssl1)
#         index_matrix=ss_airway_modeling(index_matrix,ssl2)
#         index_matrix=ss_airway_modeling(index_matrix,ssl3)
#         index_matrix=ss_airway_modeling(index_matrix,ssl4)
#         index_matrix=ss_airway_modeling(index_matrix,ssl5)
#         index_matrix=ss_airway_modeling(index_matrix,ssl6)
#         index_matrix=ss_airway_modeling(index_matrix,ssl8)
#         index_matrix=ss_airway_modeling(index_matrix,ssl9)
#         index_matrix=ss_airway_modeling(index_matrix,ssl10)
#         print ("swaping axes")
#         index_matrix=np.array(index_matrix,dtype="f")
#         index_matrix=np.swapaxes(index_matrix,0,2).copy()
#         end=time.time()
#         print(end-start,'s')
#         return index_matrix
    
#     def generating_label_image(index_matrix):
#         start=time.time()
#         print ("generating main branch")
#         index_matrix=airway_modeling(index_matrix,trachea_i,trachea,1000)
#         index_matrix=airway_modeling(index_matrix,rm_i,rm,1020)
#         index_matrix=airway_modeling(index_matrix,ru_i,ru,1040)
#         index_matrix=airway_modeling(index_matrix,br_i,br,1060)
#         index_matrix=airway_modeling(index_matrix,r45_i,r45,1080)
#         index_matrix=airway_modeling(index_matrix,r6_i,r6,1100)
#         index_matrix=airway_modeling(index_matrix,rl7_i,rl7,1120)
#         index_matrix=airway_modeling(index_matrix,rl_i,rl,1140)
#         index_matrix=airway_modeling(index_matrix,r910_i,r910,1160)
#         index_matrix=airway_modeling(index_matrix,r8_i,r8,1180)
#         index_matrix=airway_modeling(index_matrix,r9_i,r9,1200)
#         index_matrix=airway_modeling(index_matrix,r10_i,r10,1220)
#         index_matrix=airway_modeling(index_matrix,r4_i,r4,1240)
#         index_matrix=airway_modeling(index_matrix,r5_i,r5,1260)
#         index_matrix=airway_modeling(index_matrix,r7_i,r7,1280)
#         index_matrix=airway_modeling(index_matrix,r1_i,r8,1300)
#         index_matrix=airway_modeling(index_matrix,r2_i,r2,1320)
#         index_matrix=airway_modeling(index_matrix,r3_i,r3,1340)
#         index_matrix=airway_modeling(index_matrix,lm_i,lm,500)
#         index_matrix=airway_modeling(index_matrix,ll6_i,ll6,520)
#         index_matrix=airway_modeling(index_matrix,l6_i,l6,540)
#         index_matrix=airway_modeling(index_matrix,ll_i,ll,560)
#         index_matrix=airway_modeling(index_matrix,l8_i,l8,580)
#         index_matrix=airway_modeling(index_matrix,l910_i,l910,600)
#         index_matrix=airway_modeling(index_matrix,l123_i,l123,620)
#         index_matrix=airway_modeling(index_matrix,l12_i,l12,640)
#         index_matrix=airway_modeling(index_matrix,l1_i,l1,660)
#         index_matrix=airway_modeling(index_matrix,l2_i,l2,680)
#         index_matrix=airway_modeling(index_matrix,l3_i,l3,700)
#         index_matrix=airway_modeling(index_matrix,l45_i,l45,720)
#         index_matrix=airway_modeling(index_matrix,l4_i,l4,740)
#         index_matrix=airway_modeling(index_matrix,l5_i,l5,760)
#         index_matrix=airway_modeling(index_matrix,lu_i,lu,780)
#         index_matrix=airway_modeling(index_matrix,l9_i,l9,800)
#         index_matrix=airway_modeling(index_matrix,l10_i,l10,820)

#         print ("generating son branch")
#         index_matrix=s_airway_modeling(index_matrix,sr1)
#         index_matrix=s_airway_modeling(index_matrix,sr2)
#         index_matrix=s_airway_modeling(index_matrix,sr3)
#         index_matrix=s_airway_modeling(index_matrix,sr4)
#         index_matrix=s_airway_modeling(index_matrix,sr5)
#         index_matrix=s_airway_modeling(index_matrix,sr6)
#         index_matrix=s_airway_modeling(index_matrix,sr7)
#         index_matrix=s_airway_modeling(index_matrix,sr8)
#         index_matrix=s_airway_modeling(index_matrix,sr9)
#         index_matrix=s_airway_modeling(index_matrix,sr10)
#         index_matrix=s_airway_modeling(index_matrix,sl1)
#         index_matrix=s_airway_modeling(index_matrix,sl2)
#         index_matrix=s_airway_modeling(index_matrix,sl3)
#         index_matrix=s_airway_modeling(index_matrix,sl4)
#         index_matrix=s_airway_modeling(index_matrix,sl5)
#         index_matrix=s_airway_modeling(index_matrix,sl6)
#         index_matrix=s_airway_modeling(index_matrix,sl8)
#         index_matrix=s_airway_modeling(index_matrix,sl9)
#         index_matrix=s_airway_modeling(index_matrix,sl10)

#         print("generating grandson branch")
#         index_matrix=ss_airway_modeling(index_matrix,ssr1)
#         index_matrix=ss_airway_modeling(index_matrix,ssr2)
#         index_matrix=ss_airway_modeling(index_matrix,ssr3)
#         index_matrix=ss_airway_modeling(index_matrix,ssr4)
#         index_matrix=ss_airway_modeling(index_matrix,ssr5)
#         index_matrix=ss_airway_modeling(index_matrix,ssr6)
#         index_matrix=ss_airway_modeling(index_matrix,ssr7)
#         index_matrix=ss_airway_modeling(index_matrix,ssr8)
#         index_matrix=ss_airway_modeling(index_matrix,ssr9)
#         index_matrix=ss_airway_modeling(index_matrix,ssr10)
#         index_matrix=ss_airway_modeling(index_matrix,ssl1)
#         index_matrix=ss_airway_modeling(index_matrix,ssl2)
#         index_matrix=ss_airway_modeling(index_matrix,ssl3)
#         index_matrix=ss_airway_modeling(index_matrix,ssl4)
#         index_matrix=ss_airway_modeling(index_matrix,ssl5)
#         index_matrix=ss_airway_modeling(index_matrix,ssl6)
#         index_matrix=ss_airway_modeling(index_matrix,ssl8)
#         index_matrix=ss_airway_modeling(index_matrix,ssl9)
#         index_matrix=ss_airway_modeling(index_matrix,ssl10)
#         print ("swaping axes")
#         index_matrix=np.array(index_matrix,dtype="f")
#         index_matrix=np.swapaxes(index_matrix,0,2).copy()
#         end=time.time()
#         print(end-start,'s')
#         return index_matrix
    
#     def image_test_generation(index_matrix):
#         index_matrix=generating_test_image(index_matrix)
#         print (np.amax(index_matrix))
#         print ("generating test Image")
#         image=itk.GetImageFromArray(index_matrix)
#         image.SetSpacing([0.5,0.5,0.5])
#         return image
#     image_t=image_test_generation(np.zeros((720,720,768)))
#     def image_label_generation(index_matrix):
#         index_matrix=generating_label_image(index_matrix)
#         print (np.amax(index_matrix))
#         image=itk.GetImageFromArray(index_matrix)
#         image.SetSpacing([0.5,0.5,0.5])
#         return image
#     image_l=image_label_generation(np.zeros((720,720,768)))
  

#     subjectid='{num:04d}'.format(num=num_id)
#     ImageType = itk.Image[itk.F, 3]
#     WriterType = itk.ImageFileWriter[ImageType]
#     writer = WriterType.New()
#     writer.SetFileName('labeled/'+subjectid+'labled.nii.gz')
#     writer.SetInput(image_l)
#     writer.Update()
#     writer.SetFileName('test/'+subjectid+'origin.nii.gz')
#     writer.SetInput(image_t)
#     writer.Update()
#     print ('imageset'+subjectid+'complete')

# %% [markdown]
# ## ver 0.1
# cylinder air way >> cone airway

# %%
# def test_ge():
#     def index_matrix_generation():
#         index_matrix=np.zeros((720,720,768))
#         return index_matrix
#     index_matrix_tree=index_matrix_generation()


#     # In[3]:


#     def seed_generation():
#         #set starting seed at trechea
#         mu = 6 #
#         sigma = 2 
#         rand_pos = np.random.normal(mu, sigma, 3)
#         seed=np.array([int(rand_pos[0]),int(rand_pos[1])-20,80])
#         return seed
#     seed=seed_generation()


#     # ## Main branch parameter generation

#     # In[4]:


#     def parameter_generation(cl_mean,cl_sig,r_mean,r_sig,phi_min,phi_max,theta_min,theta_max,wall_mean,wall_sig):
#         cl=np.random.normal(cl_mean,cl_sig)
#         if cl<0:
#             cl=0
#         r=np.random.normal(r_mean,r_sig)
    
#         phi=np.random.randint(phi_min,phi_max)/180*np.pi
#         theta=np.random.randint(theta_min,theta_max)/180*np.pi
#         wall=np.random.normal(wall_mean,wall_sig)
#         return np.array([cl,r,phi,theta,wall])


#     # In[5]:


#     def normalized_parameter_generation(cl_mean,cl_sig,rn_mean,rn_sig,phi_min,phi_max,theta_min,theta_max,wall_mean,wall_sig,Trachea_r,limit=[0,0]):
#         cl=np.random.normal(cl_mean,cl_sig)
#         if cl<0:
#             cl=0
#     #     if cl>=1.5*limit[0]:
#     #         cl=1.5*limit[0]
#         r=np.random.normal(rn_mean,rn_sig/1.2)*Trachea_r
#         phi=np.random.randint(phi_min,phi_max)/180*np.pi
#         theta=np.random.randint(theta_min,theta_max)/180*np.pi
#         if limit[1] >0:
#             r=min(limit[1],r)
#         wall=np.random.normal(wall_mean,wall_sig)
#         return np.array([cl,r,phi,theta,wall])


#     # In[6]:


#     trachea=parameter_generation(109,14,23.9,2.9,85,95,18,20,2.6,0.24)## radius needed and centerline length needed
#     R=trachea[1]
#     rm=normalized_parameter_generation(25.5,2.5,0.84,0.13,175,185,30,35,2.3,0.33,R)
#     ru=normalized_parameter_generation(15,4,0.59,0.17,180,210,85,105,1.8,0.3,R,rm)
#     br=normalized_parameter_generation(29,3,0.653,0.11,175,195,30,45,1.82,0.25,R,rm)
#     r45=normalized_parameter_generation(19,4,0.38,0.09,180,225,60,90,1.6,0.15,R,br)
#     r6=normalized_parameter_generation(10,4,0.36,0.1,105,145,60,90,1.61,0.3,R,br)
#     rl7=normalized_parameter_generation(10.5,1.25,0.463,0.08,175,195,20,40,1.74,0.22,R,br)
#     r7=normalized_parameter_generation(16,5,0.27,0.06,-105,-30,30,45,1.45,0.17,R,rl7)
#     rl=normalized_parameter_generation(10,4,0.41,0.1,175,195,20,40,1.6,0.21,R,rl7)
#     r8=normalized_parameter_generation(12.5,1.5,0.296,0.073,195,255,45,60,1.51,0.17,R)
#     r910=normalized_parameter_generation(11,3.5,0.366,0.083,175,195,20,40,1.61,0.15,R,rl)
#     r9=normalized_parameter_generation(15,3.5,0.262,0.06,175,195,20,45,1.38,0.21,R,r910)
#     r10=normalized_parameter_generation(13,3.5,3.03,0.074,-30,30,0,45,1.45,0.16,R,r910)
#     r1=normalized_parameter_generation(13,3.5,0.33,0.06,-90,180,135,180,1.5,0.22,R,ru)
#     r2=normalized_parameter_generation(11,3,0.31,0.061,90,135,75,100,1.48,0.16,R,ru)
#     r3=normalized_parameter_generation(12,3.75,0.35,0.096,225,250,90,120,1.61,0.18,R,ru)
#     r4=normalized_parameter_generation(12.5,4,0.27,0.07,150,180,60,90,1.4,0.16,R,r45)
#     r5=normalized_parameter_generation(14,4,0.29,0.06,195,225,60,90,1.47,0.17,R,r45)
#     print (r2,r3)
#     lm=normalized_parameter_generation(50,5,0.7,0.11,-15,5,30,35,2.06,0.34,R)
#     lu=normalized_parameter_generation(13,3,0.58,0.18,-45,0,85,105,1.92,0.3,R,lm)
#     ll6=normalized_parameter_generation(12.5,2.5,0.6,0.13,-15,5,30,45,1.97,0.32,R,lm)
#     l6=normalized_parameter_generation(10,2.8,0.41,0.15,55,105,50,90,1.71,0.22,R,ll6)
#     ll=normalized_parameter_generation(17,4,0.47,0.1,-15,5,30,45,1.76,0.15,R,ll6)
#     l8=normalized_parameter_generation(12.5,4,0.32,0.07,-75,5,45,60,1.57,0.15,R,ll)
#     l910=normalized_parameter_generation(10,3,0.42,0.1,-25,5,15,45,1.66,0.15,R,ll)
#     l9=normalized_parameter_generation(15,4.75,0.3,0.075,-35,0,20,45,1.48,0.21,R,l910)#cl=15
#     l10=normalized_parameter_generation(15,4.75,0.32,0.075,5,25,20,45,1.5,0.17,R,l910)#cl=15
#     l123=normalized_parameter_generation(11.5,3,0.454,0.125,-90,90,160,180,1.75,0.19,R,lu)
#     l12=normalized_parameter_generation(6,2.5,0.33,0.1,120,240,120,180,1.56,0.37,R,l123)
#     l1=normalized_parameter_generation(13,3.5,0.263,0.08,90,150,150,180,1.38,0.188,R,l12)
#     l2=normalized_parameter_generation(12.5,3,0.225,0.06,150,210,150,180,1.27,0.24,R,l12)
#     l3=normalized_parameter_generation(10,3,0.33,0.09,-60,60,120,150,1.57,0.175,R,l123)
#     l45=normalized_parameter_generation(14,5,0.40,0.1,-15,30,60,75,1.62,0.41,R,lu,)
#     l4=normalized_parameter_generation(12.5,5,0.264,0.05,-15,30,60,75,1.36,0.16,R,l45)
#     l5=normalized_parameter_generation(12.5,3.5,0.26,0.06,15,30,45,60,1.35,0.16,R,l45)


#     # ## One-D Tree generation

#     # In[7]:


#     def main_branch_generation(seed,index_matrix,branch,base=[0,0,0,0],label=60,vanish=1,bifurcate=1):
#         length=int(branch[0]*2)
#         phi=branch[2]
#         theta=branch[3]
#         base_r=int(base[1])
#         x=np.zeros((length))
#         y=np.zeros((length))
#         z=np.zeros((length))
#         x1=x
#         y1=y
#         z1=z
#         line=np.zeros((length))
#         line1=line
#         prob_v=np.random.binomial(1,vanish,1)[0]
#         prob_b=np.random.binomial(1,bifurcate,1)[0]
#         for i in range (0,length):
#             x[i]=int((base_r*0.95+i)*np.sin(theta)*np.cos(phi))+seed[0]
#             y[i]=int((base_r*0.95+i)*np.sin(theta)*np.sin(phi))+seed[1]
#             z[i]=int((base_r*0.95+i)*np.cos(theta))+seed[2]
#             line[i]=label
#             index_matrix[int(x[i])+360,int(y[i])+360,int(z[i])]=line[i]
#             if prob_v==0:
#                 index_matrix[int(x[i])+360,int(y[i])+360,int(z[i])]=0
#         end=length-1
#     #     end=np.array([x[end],y[end],z[end]])
#     #     if prob_v==0:
#     #         end=seed
#     #     if prob_b==0:
#     #         theta1=theta+np.random.randint(15,30)/180*np.pi
#     #         for j in range (0,length):
#     #             x1[j]=int((base_r+j)*np.sin(theta1)*np.cos(phi))+seed[0]
#     #             y1[j]=int((base_r+j)*np.sin(theta1)*np.sin(phi))+seed[1]
#     #             z1[j]=int((base_r+j)*np.cos(theta1))+seed[2]
#     #             line1[j]=label
#     #             index_matrix[int(x1[j])+360,int(y1[j])+360,int(z1[j])]=line1[j]
#     #         x=np.hstack((x,x1))
#     #         y=np.hstack((y,y1))
#     #         z=np.hstack((z,z1))
#         info=np.array([(x[0],y[0],z[0]),(x[end],y[end],z[end])])
#         return index_matrix,info


#     # In[8]:


#     def s_branch_generation (index_matrix,f_branch,seed,label=100):
#         length_factor=np.random.normal(7,1,2)/10
#         radius_factor=np.random.normal(6.5,0.8,2)/10
#     #     radius_factor=np.array([0.5,0.5])
#         theta_1=f_branch[3]+np.random.randint(5,22)/180*np.pi
#         theta_2=f_branch[3]-np.random.randint(5,22)/180*np.pi
#         phi_1=np.random.randint(15,20)/180+f_branch[2]
#         phi_2=f_branch[2]-np.random.randint(10,20)/180
#         length_1=int(length_factor[0]*f_branch[0]*2)
#         length_2=int(length_factor[1]*f_branch[0]*2)

#         x=np.zeros((length_1))
#         y=np.zeros((length_1))
#         z=np.zeros((length_1))
#         x1=np.zeros((length_2))
#         y1=np.zeros((length_2))
#         z1=np.zeros((length_2))
#         for i in range (0,length_1):
#             x[i]=int((f_branch[1]+i)*np.sin(theta_1)*np.cos(phi_1))+seed[1,0]
#             y[i]=int((f_branch[1]+i)*np.sin(theta_1)*np.sin(phi_1))+seed[1,1]
#             z[i]=int((f_branch[1]+i)*np.cos(theta_1))+seed[1,2]

#             index_matrix[int(x[i])+360,int(y[i])+360,int(z[i])]=label

#         l=len(x)-1
#         s_branch=[(x[0],y[0],z[0]),(x[l],y[l],z[l])]



#         for j in range (0,length_2):
#             x1[j]=int((f_branch[1]+j)*np.sin(theta_2)*np.cos(phi_2))+seed[1,0]
#             y1[j]=int((f_branch[1]+j)*np.sin(theta_2)*np.sin(phi_2))+seed[1,1]
#             z1[j]=int((f_branch[1]+j)*np.cos(theta_2))+seed[1,2]

#             index_matrix[int(x1[j])+360,int(y1[j])+360,int(z1[j])]=label
#     #         index_matrix1[int(x1[j])+360,int(y1[j])+360,int(z1[j])]=label
#         l1=length_2-1
#         s1_branch=[(x1[0],y1[0],z1[0]),(x1[l1],y1[l1],z1[l1])]
#     #     x=np.hstack((x,x1))
#     #     y=np.hstack((y,y1))
#     #     z=np.hstack((z,z1))
#         radius=radius_factor*f_branch[1]
#     #     print (s1_branch)

#         ends=np.array([(length_1,radius[0],phi_1,theta_1,x[0],y[0],z[0],x[l],y[l],z[l]),(length_2,radius[1],phi_2,theta_2,x1[0],y1[0],z1[0],x1[l1],y1[l1],z1[l1])])
#         return index_matrix,ends


#     # In[9]:


#     def ss_branch_generation0 (index_matrix,f_branch,label=60):
#         length_factor=np.random.normal(7.5,0.3,2)/10
#         radius_factor=np.random.normal(6.5,0.8,2)/10

#     #     radius_factor=np.array([0.5,0.5])
#         theta_1=f_branch[3]+np.random.randint(5,22)/180*np.pi
#         theta_2=f_branch[3]-np.random.randint(5,22)/180*np.pi
#         phi_1=np.random.randint(15,20)/180+f_branch[2]
#         phi_2=f_branch[2]-np.random.randint(10,20)/180
#         length_1=int(length_factor[0]*f_branch[0]*2)
#         if length_1<1:
#             length_1=2
#         length_2=int(length_factor[1]*f_branch[0]*2)
#         if length_2<1:
#             length_2=2
#     #     print (length_1,length_2)
#         x=np.zeros((length_1))
#         y=np.zeros((length_1))
#         z=np.zeros((length_1))
#         x1=np.zeros((length_2))
#         y1=np.zeros((length_2))
#         z1=np.zeros((length_2))
#         for i in range (0,length_1):
#             x[i]=int((f_branch[1]+i)*np.sin(theta_1)*np.cos(phi_1))+f_branch[7]
#             y[i]=int((f_branch[1]+i)*np.sin(theta_1)*np.sin(phi_1))+f_branch[8]
#             z[i]=int((f_branch[1]+i)*np.cos(theta_1))+f_branch[9]

#             index_matrix[int(x[i])+360,int(y[i])+360,int(z[i])]=label

#         l=length_1-1
#         s_branch=[(x[0],y[0],z[0]),(x[l],y[l],z[l])]



#         for j in range (0,length_2):
#             x1[j]=int((f_branch[1]+j)*np.sin(theta_2)*np.cos(phi_2))+f_branch[7]
#             y1[j]=int((f_branch[1]+j)*np.sin(theta_2)*np.sin(phi_2))+f_branch[8]
#             z1[j]=int((f_branch[1]+j)*np.cos(theta_2))+f_branch[9]

#             index_matrix[int(x1[j])+360,int(y1[j])+360,int(z1[j])]=label

#         l1=length_2-1
#         s1_branch=[(x1[0],y1[0],z1[0]),(x1[l1],y1[l1],z1[l1])]
#     #     x=np.hstack((x,x1))
#     #     y=np.hstack((y,y1))
#     #     z=np.hstack((z,z1))
#         radius=radius_factor*f_branch[1]
#     #     print (s1_branch)
#     #     print (radius)
#         ends=np.array([(length_1,radius[0],phi_1,theta_1,x[0],y[0],z[0],x[l],y[l],z[l]),(length_2,radius[1],phi_2,theta_2,x1[0],y1[0],z1[0],x1[l1],y1[l1],z1[l1])])
#         return index_matrix,ends

#     def ss_branch_generation(index_matrix,ends):
#         f_branch_0=ends[0]
#     #     print(f_branch_0)
#         f_branch_1=ends[1]
#     #     print(f_branch_1)
#         index_matrix,ends1=ss_branch_generation0(index_matrix,f_branch_0)
#         index_matrix,ends2=ss_branch_generation0(index_matrix,f_branch_1)
#         ends=np.vstack((ends1,ends2))

#         return index_matrix,ends



#     # In[10]:


#     index_matrix_tree,trachea_i=main_branch_generation(seed,index_matrix_tree,trachea)
#     #rmb
#     index_matrix_tree,rm_i=main_branch_generation(trachea_i[1],index_matrix_tree,rm,trachea)
#     #rul
#     index_matrix_tree,ru_i=main_branch_generation(rm_i[1],index_matrix_tree,ru,rm)
#     #bronlnt
#     index_matrix_tree,br_i=main_branch_generation(rm_i[1],index_matrix_tree,br,rm)
#     #rb4+5
#     index_matrix_tree,r45_i=main_branch_generation(br_i[1],index_matrix_tree,r45,br)
#     #rb6
#     index_matrix_tree,r6_i=main_branch_generation(br_i[1],index_matrix_tree,r6,br)
#     #rll7
#     index_matrix_tree,rl7_i=main_branch_generation(br_i[1],index_matrix_tree,rl7,br)
#     #rb7(future needs a vanish factor)
#     index_matrix_tree,r7_i=main_branch_generation(rl7_i[1],index_matrix_tree,r7,rl7)
#     #rll
#     index_matrix_tree,rl_i=main_branch_generation(rl7_i[1],index_matrix_tree,rl7)
#     #rb8(needs bifurcation factor)
#     index_matrix_tree,r8_i=main_branch_generation(rl_i[1],index_matrix_tree,r8,rl)
#     #rb9+10(needs a vanish factor)
#     index_matrix_tree,r910_i=main_branch_generation(rl_i[1],index_matrix_tree,r910,rl)
#     #rb9
#     index_matrix_tree,r9_i=main_branch_generation(r910_i[1],index_matrix_tree,r9,r910)
#     #rb10
#     index_matrix_tree,r10_i=main_branch_generation(r910_i[1],index_matrix_tree,r10,r910)
#     #rb1
#     index_matrix_tree,r1_i=main_branch_generation(ru_i[1],index_matrix_tree,r1,ru)
#     #rb2
#     index_matrix_tree,r2_i=main_branch_generation(ru_i[1],index_matrix_tree,r2,ru)
#     #rb3
#     index_matrix_tree,r3_i=main_branch_generation(ru_i[1],index_matrix_tree,r3,ru)
#     #rb4
#     index_matrix_tree,r4_i=main_branch_generation(r45_i[1],index_matrix_tree,r4,r45)
#     #rb5
#     index_matrix_tree,r5_i=main_branch_generation(r45_i[1],index_matrix_tree,r5,r45)
#     #lmb
#     index_matrix_tree,lm_i=main_branch_generation(trachea_i[1],index_matrix_tree,lm,trachea)
#     #lul
#     index_matrix_tree,lu_i=main_branch_generation(lm_i[1],index_matrix_tree,lu,lm)
#     #llb6
#     index_matrix_tree,ll6_i=main_branch_generation(lm_i[1],index_matrix_tree,ll6,lm)
#     #lb6
#     index_matrix_tree,l6_i=main_branch_generation(ll6_i[1],index_matrix_tree,l6,ll6)
#     #llb
#     index_matrix_tree,ll_i=main_branch_generation(ll6_i[1],index_matrix_tree,ll,ll6)
#     #lb8
#     index_matrix_tree,l8_i=main_branch_generation(ll_i[1],index_matrix_tree,l8,ll)
#     #lb9+10
#     index_matrix_tree,l910_i=main_branch_generation(ll_i[1],index_matrix_tree,l910,ll)
#     #lb9
#     index_matrix_tree,l9_i=main_branch_generation(l910_i[1],index_matrix_tree,l9,l910)
#     #lb10
#     index_matrix_tree,l10_i=main_branch_generation(l910_i[1],index_matrix_tree,l10,l910)
#     #lb1+2+3
#     index_matrix_tree,l123_i=main_branch_generation(lu_i[1],index_matrix_tree,l123,lu)
#     #lb1+2
#     index_matrix_tree,l12_i=main_branch_generation(l123_i[1],index_matrix_tree,l12,l123)
#     #lb3
#     index_matrix_tree,l3_i=main_branch_generation(l123_i[1],index_matrix_tree,l3,l123)
#     #lb1
#     index_matrix_tree,l1_i=main_branch_generation(l12_i[1],index_matrix_tree,l1,l12)
#     #lb2
#     index_matrix_tree,l2_i=main_branch_generation(l12_i[1],index_matrix_tree,l2,l12)
#     #lb4+5
#     index_matrix_tree,l45_i=main_branch_generation(lu_i[1],index_matrix_tree,l45,lu)
#     #lb4
#     index_matrix_tree,l4_i=main_branch_generation(l45_i[1],index_matrix_tree,l4,l45)
#     #lb5
#     index_matrix_tree,l5_i=main_branch_generation(l45_i[1],index_matrix_tree,l5,l45)    


#     # In[11]:


#     index_matrix_tree,sr1=s_branch_generation(index_matrix_tree,r1,r1_i)
#     index_matrix_tree,sr2=s_branch_generation(index_matrix_tree,r2,r2_i)
#     index_matrix_tree,sr3=s_branch_generation(index_matrix_tree,r3,r3_i)
#     index_matrix_tree,sr4=s_branch_generation(index_matrix_tree,r4,r4_i)
#     index_matrix_tree,sr5=s_branch_generation(index_matrix_tree,r5,r5_i)
#     index_matrix_tree,sr6=s_branch_generation(index_matrix_tree,r6,r6_i)
#     index_matrix_tree,sr7=s_branch_generation(index_matrix_tree,r7,r7_i)
#     index_matrix_tree,sr8=s_branch_generation(index_matrix_tree,r8,r8_i)
#     index_matrix_tree,sr9=s_branch_generation(index_matrix_tree,r9,r9_i)
#     index_matrix_tree,sr10=s_branch_generation(index_matrix_tree,r10,r10_i)
#     index_matrix_tree,sl1=s_branch_generation(index_matrix_tree,l1,l1_i)
#     index_matrix_tree,sl2=s_branch_generation(index_matrix_tree,l2,l2_i)
#     index_matrix_tree,sl3=s_branch_generation(index_matrix_tree,l3,l3_i)
#     index_matrix_tree,sl4=s_branch_generation(index_matrix_tree,l4,l4_i)
#     index_matrix_tree,sl5=s_branch_generation(index_matrix_tree,l5,l5_i)
#     index_matrix_tree,sl6=s_branch_generation(index_matrix_tree,l6,l6_i)
#     index_matrix_tree,sl8=s_branch_generation(index_matrix_tree,l8,l8_i)
#     index_matrix_tree,sl9=s_branch_generation(index_matrix_tree,l9,l9_i)
#     index_matrix_tree,sl10=s_branch_generation(index_matrix_tree,l10,l10_i)


#     # In[12]:


#     index_matrix_tree,ssr1=ss_branch_generation(index_matrix_tree,sr1)
#     index_matrix_tree,ssr2=ss_branch_generation(index_matrix_tree,sr2)
#     index_matrix_tree,ssr3=ss_branch_generation(index_matrix_tree,sr3)
#     index_matrix_tree,ssr4=ss_branch_generation(index_matrix_tree,sr4)
#     index_matrix_tree,ssr5=ss_branch_generation(index_matrix_tree,sr5)
#     index_matrix_tree,ssr6=ss_branch_generation(index_matrix_tree,sr6)
#     index_matrix_tree,ssr7=ss_branch_generation(index_matrix_tree,sr7)
#     index_matrix_tree,ssr8=ss_branch_generation(index_matrix_tree,sr8)
#     index_matrix_tree,ssr9=ss_branch_generation(index_matrix_tree,sr9)
#     index_matrix_tree,ssr10=ss_branch_generation(index_matrix_tree,sr10)
#     index_matrix_tree,ssl1=ss_branch_generation(index_matrix_tree,sl1)
#     index_matrix_tree,ssl2=ss_branch_generation(index_matrix_tree,sl2)
#     index_matrix_tree,ssl3=ss_branch_generation(index_matrix_tree,sl3)
#     index_matrix_tree,ssl4=ss_branch_generation(index_matrix_tree,sl4)
#     index_matrix_tree,ssl5=ss_branch_generation(index_matrix_tree,sl5)
#     index_matrix_tree,ssl6=ss_branch_generation(index_matrix_tree,sl6)
#     index_matrix_tree,ssl8=ss_branch_generation(index_matrix_tree,sl8)
#     index_matrix_tree,ssl9=ss_branch_generation(index_matrix_tree,sl9)
#     index_matrix_tree,ssl10=ss_branch_generation(index_matrix_tree,sl10)



#     # In[13]:


# #     index_matrix1=np.copy(index_matrix)



#     # ## Airway Modeling

#     # In[14]:
# #     matrix0=index_matrix_generation()
# #     matrix1=index_matrix_generation()

#     def airway_modeling(index_matrix,info,branch,s_branch1,s_branch2,num_id=60):
#     #     start=time.time()
#         P=info[0]+[360,360,0]
#         Q=info[1]+[360,360,0]
#         AB = Q - P;
#         temp = AB / np.dot(AB,AB);
#         r1=branch[1]
#         r2=max(s_branch1[1],s_branch2[1])
#         rf=(r2-r1)

#         lmin=int(min(P[0],Q[0])-1.2*int(r1))
#         lmax=int(max(P[0],Q[0])+1.2*int(r1))
#         wmin=int(min(P[1],Q[1])-1.2*int(r1))
#         wmax=int(max(P[1],Q[1])+1.2*int(r1))
#         hmin=int(min(P[2],Q[2])-1*int(r1))
#         if hmin<0:
#             hmin=0
#         hmax=int(max(P[2],Q[2])+1*int(r1)+1)

#         x_range = np.sort(np.array([P[0], Q[0]]));
#         y_range = np.sort(np.array([P[1], Q[1]]));
#         z_range = np.sort(np.array([P[2], Q[2]]));
#         #for any point on line x^2+y^2+z^2=<r^2
#         for i in range(lmin,lmax):       
#             for j in range (wmin,wmax):
#                 for k in range(hmin,hmax):
#                     p = np.array([i, j, k])
#                     AP = p - P;
#                     BP = p - Q
#                     proj_point = P + np.dot(AP,AB) * temp;
#                     distance_s = (proj_point[0] - p[0])**2 + (proj_point[1] - p[1])**2 + (proj_point[2] - p[2])**2;
#                     distance_1_s = (P[0] - p[0])**2 + (P[1] - p[1])**2 + (P[2] - p[2])**2;
#                     distance_2_s = (Q[0] - p[0])**2 + (Q[1] - p[1])**2 + (Q[2] - p[2])**2;
#                     r=r1+rf*(np.dot(AP,AP)/np.dot(AB,AB))*0.5
#                     ri=r-2*branch[4]

#                     if distance_s <=r*r and index_matrix[i,j,k]==0 and (x_range[0] <= proj_point[0] and proj_point[0] <= x_range[1]) and (
#                                 y_range[0] <= proj_point[1] and proj_point[1] <= y_range[1]) and (
#                                         z_range[0] <= proj_point[2] and proj_point[2] <= z_range[1]) or distance_1_s<=r*r or distance_2_s<=r*r:
#                         if index_matrix[i,j,k]==0:


#                             index_matrix[i,j,k]=num_id
#                     if distance_s <=ri*ri and (x_range[0] <= proj_point[0] and proj_point[0] <= x_range[1]) and (
#                                 y_range[0] <= proj_point[1] and proj_point[1] <= y_range[1]) and (
#                                         z_range[0] <= proj_point[2] and proj_point[2] <= z_range[1]) or distance_1_s<=ri*ri or distance_2_s<=ri*ri:
#                         index_matrix[i,j,k]=255


#     #     end=time.time()
#     #     print (end-start,"s")
#         return index_matrix#,xx,yy,zz


#     # In[15]:


#     #np.array([(length_1,radius[0],phi_1,theta_1,x[0],y[0],z[0],x[l],y[l],z[l]),(length_2,radius[1],phi_2,theta_2,x1[0],y1[0],z1[0],x1[l1],y1[l1],z1[l1])])
#     def s_airway_modeling0(index_matrix,s_branch,num_id=100):
#     #     start=time.time()
#         P=np.array(s_branch)[4:7]+[360,360,0]
#         Q=np.array(s_branch)[7:10]+[360,360,0]
#         AB = Q - P;
#         temp = AB / np.dot(AB,AB);
#         r=s_branch[1]
#         ri=0.6*r


#         lmin=int(min(P[0],Q[0])-1.5*int(r))
#         lmax=int(max(P[0],Q[0])+1.5*int(r))
#         wmin=int(min(P[1],Q[1])-1.5*int(r))
#         wmax=int(max(P[1],Q[1])+1.5*int(r))
#         hmin=int(min(P[2],Q[2])-1.5*int(r))
#         if hmin<0:
#             hmin=0
#         hmax=int(max(P[2],Q[2])+1.5*int(r)+1)

#         x_range = np.sort(np.array([P[0], Q[0]]));
#         y_range = np.sort(np.array([P[1], Q[1]]));
#         z_range = np.sort(np.array([P[2], Q[2]]));
#         #for any point on line x^2+y^2+z^2=<r^2
#         for i in range(lmin,lmax):       
#             for j in range (wmin,wmax):
#                 for k in range(hmin,hmax):
#                     p = np.array([i, j, k])
#                     AP = p - P;
#                     BP = p - Q
#                     proj_point = P + np.dot(AP,AB) * temp;
#                     distance_s = (proj_point[0] - p[0])**2 + (proj_point[1] - p[1])**2 + (proj_point[2] - p[2])**2;
#                     distance_1_s = (P[0] - p[0])**2 + (P[1] - p[1])**2 + (P[2] - p[2])**2;
#                     distance_2_s = (Q[0] - p[0])**2 + (Q[1] - p[1])**2 + (Q[2] - p[2])**2;

#     #                 if distance_s <=r*r or distance_t1<=r*r or distance_t2<=r*r and index_matrix[i,k,k]==0:
#                     if distance_s <=r*r and index_matrix[i,j,k]==0 and (x_range[0] <= proj_point[0] and proj_point[0] <= x_range[1]) and (
#                                 y_range[0] <= proj_point[1] and proj_point[1] <= y_range[1]) and (
#                                         z_range[0] <= proj_point[2] and proj_point[2] <= z_range[1]) or distance_1_s<=r*r or distance_2_s<=r*r:
#                         if index_matrix[i,k,k]==0:


#                             index_matrix[i,j,k]=num_id

#                     if distance_s <=ri*ri and (x_range[0] <= proj_point[0] and proj_point[0] <= x_range[1]) and (
#                                 y_range[0] <= proj_point[1] and proj_point[1] <= y_range[1]) and (
#                                         z_range[0] <= proj_point[2] and proj_point[2] <= z_range[1]) or distance_1_s<=ri*ri or distance_2_s<=ri*ri:
#                         index_matrix[i,j,k]=255
#     #     end=time.time()
#     #     print (end-start,"s")
#         return index_matrix#,xx,yy,zz

#     def s_airway_modeling(index_matrix,s_branch):
#         index_matrix=s_airway_modeling0(index_matrix,s_branch[0])
#         index_matrix=s_airway_modeling0(index_matrix,s_branch[1])
#         return index_matrix


#     # In[16]:


#     def ss_airway_modeling(index_matrix,ss_branch):
#         for i in range(0,4):
#             index_matrix=s_airway_modeling0(index_matrix,ss_branch[i])
#         return index_matrix


#     # ## Generating testing image

#     # In[17]:


# #     def generating_test_image(index_matrix):
# #         start=time.time()
# #         print ("generating main branch")
# #         index_matrix=airway_modeling(index_matrix,trachea_i,trachea)
# #         index_matrix=airway_modeling(index_matrix,rm_i,rm)
# #         index_matrix=airway_modeling(index_matrix,ru_i,ru)
# #         index_matrix=airway_modeling(index_matrix,br_i,br)
# #         index_matrix=airway_modeling(index_matrix,r45_i,r45)
# #         index_matrix=airway_modeling(index_matrix,r6_i,r6)
# #         index_matrix=airway_modeling(index_matrix,rl7_i,rl7)
# #         index_matrix=airway_modeling(index_matrix,rl_i,rl)
# #         index_matrix=airway_modeling(index_matrix,r910_i,r910)
# #         index_matrix=airway_modeling(index_matrix,r8_i,r8)
# #         index_matrix=airway_modeling(index_matrix,r9_i,r9)
# #         index_matrix=airway_modeling(index_matrix,r10_i,r10)
# #         index_matrix=airway_modeling(index_matrix,r4_i,r4)
# #         index_matrix=airway_modeling(index_matrix,r5_i,r5)
# #         index_matrix=airway_modeling(index_matrix,r7_i,r7)
# #         index_matrix=airway_modeling(index_matrix,r1_i,r8)
# #         index_matrix=airway_modeling(index_matrix,r2_i,r2)
# #         index_matrix=airway_modeling(index_matrix,r3_i,r3)
# #         index_matrix=airway_modeling(index_matrix,lm_i,lm)
# #         index_matrix=airway_modeling(index_matrix,ll6_i,ll6)
# #         index_matrix=airway_modeling(index_matrix,l6_i,l6)
# #         index_matrix=airway_modeling(index_matrix,ll_i,ll)
# #         index_matrix=airway_modeling(index_matrix,l8_i,l8)
# #         index_matrix=airway_modeling(index_matrix,l910_i,l910)
# #         index_matrix=airway_modeling(index_matrix,lu_i,lu)
# #         index_matrix=airway_modeling(index_matrix,l123_i,l123)
# #         index_matrix=airway_modeling(index_matrix,l12_i,l12)
# #         index_matrix=airway_modeling(index_matrix,l1_i,l1)
# #         index_matrix=airway_modeling(index_matrix,l2_i,l2)
# #         index_matrix=airway_modeling(index_matrix,l3_i,l3)
# #         index_matrix=airway_modeling(index_matrix,l45_i,l45)
# #         index_matrix=airway_modeling(index_matrix,l4_i,l4)
# #         index_matrix=airway_modeling(index_matrix,l5_i,l5)
# #         index_matrix=airway_modeling(index_matrix,l9_i,l9)
# #         index_matrix=airway_modeling(index_matrix,l10_i,l10)

# #         print ("generating son branch")
# #         index_matrix=s_airway_modeling(index_matrix,sr1)
# #         index_matrix=s_airway_modeling(index_matrix,sr2)
# #         index_matrix=s_airway_modeling(index_matrix,sr3)
# #         index_matrix=s_airway_modeling(index_matrix,sr4)
# #         index_matrix=s_airway_modeling(index_matrix,sr5)
# #         index_matrix=s_airway_modeling(index_matrix,sr6)
# #         index_matrix=s_airway_modeling(index_matrix,sr7)
# #         index_matrix=s_airway_modeling(index_matrix,sr8)
# #         index_matrix=s_airway_modeling(index_matrix,sr9)
# #         index_matrix=s_airway_modeling(index_matrix,sr10)
# #         index_matrix=s_airway_modeling(index_matrix,sl1)
# #         index_matrix=s_airway_modeling(index_matrix,sl2)
# #         index_matrix=s_airway_modeling(index_matrix,sl3)
# #         index_matrix=s_airway_modeling(index_matrix,sl4)
# #         index_matrix=s_airway_modeling(index_matrix,sl5)
# #         index_matrix=s_airway_modeling(index_matrix,sl6)
# #         index_matrix=s_airway_modeling(index_matrix,sl8)
# #         index_matrix=s_airway_modeling(index_matrix,sl9)
# #         index_matrix=s_airway_modeling(index_matrix,sl10)

# #         print("generating grandson branch")
# #         index_matrix=ss_airway_modeling(index_matrix,ssr1)
# #         index_matrix=ss_airway_modeling(index_matrix,ssr2)
# #         index_matrix=ss_airway_modeling(index_matrix,ssr3)
# #         index_matrix=ss_airway_modeling(index_matrix,ssr4)
# #         index_matrix=ss_airway_modeling(index_matrix,ssr5)
# #         index_matrix=ss_airway_modeling(index_matrix,ssr6)
# #         index_matrix=ss_airway_modeling(index_matrix,ssr7)
# #         index_matrix=ss_airway_modeling(index_matrix,ssr8)
# #         index_matrix=ss_airway_modeling(index_matrix,ssr9)
# #         index_matrix=ss_airway_modeling(index_matrix,ssr10)
# #         index_matrix=ss_airway_modeling(index_matrix,ssl1)
# #         index_matrix=ss_airway_modeling(index_matrix,ssl2)
# #         index_matrix=ss_airway_modeling(index_matrix,ssl3)
# #         index_matrix=ss_airway_modeling(index_matrix,ssl4)
# #         index_matrix=ss_airway_modeling(index_matrix,ssl5)
# #         index_matrix=ss_airway_modeling(index_matrix,ssl6)
# #         index_matrix=ss_airway_modeling(index_matrix,ssl8)
# #         index_matrix=ss_airway_modeling(index_matrix,ssl9)
# #         index_matrix=ss_airway_modeling(index_matrix,ssl10)
# #         print ("swaping axes")
# #         index_matrix=np.array(index_matrix,dtype="f")
# #         index_matrix=np.swapaxes(index_matrix,0,2).copy()
# #         end=time.time()
# #         print(end-start,'s')
# #         return index_matrix
    
#     def generating_label_image(index_matrix):
#         start=time.time()
#         print ("generating main branch")
#         index_matrix=airway_modeling(index_matrix,trachea_i,trachea,lm,rm,1000)
#         index_matrix=airway_modeling(index_matrix,rm_i,rm,ru,br,1020)
#         index_matrix=airway_modeling(index_matrix,ru_i,ru,r1,r2,1040)
#         index_matrix=airway_modeling(index_matrix,br_i,br,r45,r6,1060)
#         index_matrix=airway_modeling(index_matrix,r45_i,r45,r4,r5,1080)
#         index_matrix=airway_modeling(index_matrix,r6_i,r6,rl7,rl7,1100)
#         index_matrix=airway_modeling(index_matrix,rl7_i,rl7,r7,rl,1120)
#         index_matrix=airway_modeling(index_matrix,rl_i,rl,r910,r910,1140)
#         index_matrix=airway_modeling(index_matrix,r910_i,r910,r9,r10,1160)
#         index_matrix=airway_modeling(index_matrix,r8_i,r8,sr8[0],sr8[1],1180)
#         index_matrix=airway_modeling(index_matrix,r9_i,r9,sr9[0],sr9[1],1200)
#         index_matrix=airway_modeling(index_matrix,r10_i,r10,sr10[0],sr10[1],1220)
#         index_matrix=airway_modeling(index_matrix,r4_i,r4,sr4[0],sr4[1],1240)
#         index_matrix=airway_modeling(index_matrix,r5_i,r5,sr5[0],sr5[1],1260)
#         index_matrix=airway_modeling(index_matrix,r7_i,r7,sr7[0],sr7[1],1280)
#         index_matrix=airway_modeling(index_matrix,r1_i,r1,sr1[0],sr1[1],1300)
#         index_matrix=airway_modeling(index_matrix,r2_i,r2,sr2[0],sr2[1],1320)
#         index_matrix=airway_modeling(index_matrix,r3_i,r3,sr3[0],sr3[1],1340)
#         index_matrix=airway_modeling(index_matrix,lm_i,lm,lu,ll6,500)
#         index_matrix=airway_modeling(index_matrix,lu_i,lu,l123,ll6,780)
#         index_matrix=airway_modeling(index_matrix,ll6_i,ll6,l6,ll,520)
#         index_matrix=airway_modeling(index_matrix,l6_i,l6,sl6[0],sl6[1],540)
#         index_matrix=airway_modeling(index_matrix,ll_i,ll,l910,l8,560)
#         index_matrix=airway_modeling(index_matrix,l8_i,l8,sl8[0],sl8[1],580)
#         index_matrix=airway_modeling(index_matrix,l910_i,l910,l9,l10,600)
#         index_matrix=airway_modeling(index_matrix,l123_i,l123,l12,l3,620)
#         index_matrix=airway_modeling(index_matrix,l12_i,l12,l1,l2,1800)
#         index_matrix=airway_modeling(index_matrix,l1_i,l1,sl1[0],sl1[1],1660)
#         index_matrix=airway_modeling(index_matrix,l2_i,l2,sl2[0],sl2[1],680)
#         index_matrix=airway_modeling(index_matrix,l3_i,l3,sl3[0],sl3[1],700)
#         index_matrix=airway_modeling(index_matrix,l45_i,l45,l4,l5,720)
#         index_matrix=airway_modeling(index_matrix,l4_i,l4,sl4[0],sl4[1],740)
#         index_matrix=airway_modeling(index_matrix,l5_i,l5,sl5[0],sl5[1],760)
#         index_matrix=airway_modeling(index_matrix,l9_i,l9,sl9[0],sl9[1],800)
#         index_matrix=airway_modeling(index_matrix,l10_i,l10,sl10[0],sl10[1],820)

#         print ("generating son branch")
#         index_matrix=s_airway_modeling(index_matrix,sr1)
#         index_matrix=s_airway_modeling(index_matrix,sr2)
#         index_matrix=s_airway_modeling(index_matrix,sr3)
#         index_matrix=s_airway_modeling(index_matrix,sr4)
#         index_matrix=s_airway_modeling(index_matrix,sr5)
#         index_matrix=s_airway_modeling(index_matrix,sr6)
#         index_matrix=s_airway_modeling(index_matrix,sr7)
#         index_matrix=s_airway_modeling(index_matrix,sr8)
#         index_matrix=s_airway_modeling(index_matrix,sr9)
#         index_matrix=s_airway_modeling(index_matrix,sr10)
#         index_matrix=s_airway_modeling(index_matrix,sl1)
#         index_matrix=s_airway_modeling(index_matrix,sl2)
#         index_matrix=s_airway_modeling(index_matrix,sl3)
#         index_matrix=s_airway_modeling(index_matrix,sl4)
#         index_matrix=s_airway_modeling(index_matrix,sl5)
#         index_matrix=s_airway_modeling(index_matrix,sl6)
#         index_matrix=s_airway_modeling(index_matrix,sl8)
#         index_matrix=s_airway_modeling(index_matrix,sl9)
#         index_matrix=s_airway_modeling(index_matrix,sl10)

#         print("generating grandson branch")
#         index_matrix=ss_airway_modeling(index_matrix,ssr1)
#         index_matrix=ss_airway_modeling(index_matrix,ssr2)
#         index_matrix=ss_airway_modeling(index_matrix,ssr3)
#         index_matrix=ss_airway_modeling(index_matrix,ssr4)
#         index_matrix=ss_airway_modeling(index_matrix,ssr5)
#         index_matrix=ss_airway_modeling(index_matrix,ssr6)
#         index_matrix=ss_airway_modeling(index_matrix,ssr7)
#         index_matrix=ss_airway_modeling(index_matrix,ssr8)
#         index_matrix=ss_airway_modeling(index_matrix,ssr9)
#         index_matrix=ss_airway_modeling(index_matrix,ssr10)
#         index_matrix=ss_airway_modeling(index_matrix,ssl1)
#         index_matrix=ss_airway_modeling(index_matrix,ssl2)
#         index_matrix=ss_airway_modeling(index_matrix,ssl3)
#         index_matrix=ss_airway_modeling(index_matrix,ssl4)
#         index_matrix=ss_airway_modeling(index_matrix,ssl5)
#         index_matrix=ss_airway_modeling(index_matrix,ssl6)
#         index_matrix=ss_airway_modeling(index_matrix,ssl8)
#         index_matrix=ss_airway_modeling(index_matrix,ssl9)
#         index_matrix=ss_airway_modeling(index_matrix,ssl10)
#         print ("swaping axes")
#         index_matrix=np.array(index_matrix,dtype="f")
#         index_matrix=np.swapaxes(index_matrix,0,2).copy()
#         end=time.time()
#         print(end-start,'s')
#         return index_matrix
    
# #     def image_test_generation(index_matrix):
# #         index_matrix=generating_test_image(index_matrix)
# #         print (np.amax(index_matrix))
# #         print ("generating test Image")
# #         image=itk.GetImageFromArray(index_matrix)
# #         image.SetSpacing([0.5,0.5,0.5])
# #         return image
# #     image_t=image_test_generation(np.zeros((720,720,768)))
#     def image_label_generation(index_matrix):
#         index_matrix=generating_label_image(index_matrix)
#         print (np.amax(index_matrix))
#         image=itk.GetImageFromArray(index_matrix)
#         image.SetSpacing([0.5,0.5,0.5])
#         return image
#     def flip_image(image):
#         PixelType=itk.F
#         ImageType=itk.Image[PixelType,3]
#         flipAxes=(False,False,True)

#         flipfilter=itk.FlipImageFilter[ImageType].New()
#         flipfilter.SetInput(image)
#         flipfilter.SetFlipAxes(flipAxes)
#         flipfilter.Update()
#         return flipfilter.GetOutput()
#     image_l=flip_image(image_label_generation(np.zeros((720,720,768))))
  


#     return image_l

# %% [markdown]
# ## ver 0.2

# %%
# def test_ge():
#     def index_matrix_generation():
#         index_matrix=np.zeros((720,720,768))
#         return index_matrix
#     index_matrix_tree=index_matrix_generation()


#     # In[3]:


#     def seed_generation():
#         #set starting seed at trechea
#         mu = 6 #
#         sigma = 2 
#         rand_pos = np.random.normal(mu, sigma, 3)
#         seed=np.array([int(rand_pos[0]),int(rand_pos[1])-20,80])
#         return seed
#     seed=seed_generation()


#     # ## Main branch parameter generation

#     # In[4]:


#     def parameter_generation(cl_mean,cl_sig,r_mean,r_sig,phi_min,phi_max,theta_min,theta_max,wall_mean,wall_sig):
#         cl=np.random.normal(cl_mean,cl_sig)
#         if cl<0:
#             cl=0
#         r=np.random.normal(r_mean,r_sig)
    
#         phi=np.random.randint(phi_min,phi_max)/180*np.pi
#         theta=np.random.randint(theta_min,theta_max)/180*np.pi
#         wall=np.random.normal(wall_mean,wall_sig)
#         return np.array([cl,r,phi,theta,wall])


#     # In[5]:


#     def normalized_parameter_generation(cl_mean,cl_sig,rn_mean,rn_sig,phi_min,phi_max,theta_min,theta_max,wall_mean,wall_sig,Trachea_r,limit=[0,0]):
#         cl=np.random.normal(cl_mean,cl_sig)
#         if cl<0:
#             cl=0
#     #     if cl>=1.5*limit[0]:
#     #         cl=1.5*limit[0]
#         r=np.random.normal(rn_mean,rn_sig/1.2)*Trachea_r
#         phi=np.random.randint(phi_min,phi_max)/180*np.pi
#         theta=np.random.randint(theta_min,theta_max)/180*np.pi
#         if limit[1] >0:
#             r=min(limit[1],r)
#         wall=np.random.normal(wall_mean,wall_sig)
#         return np.array([cl,r,phi,theta,wall])


#     # In[6]:


#     trachea=parameter_generation(109,14,23.9,2.9,85,95,18,20,2.6,0.24)## radius needed and centerline length needed
#     R=trachea[1]
#     rm=normalized_parameter_generation(25.5,2.5,0.84,0.13,175,185,30,35,2.3,0.33,R)
    
#     ru=normalized_parameter_generation(15,4,0.59,0.17,185,225,85,105,1.8,0.3,R,rm)
    
#     br=normalized_parameter_generation(29,3,0.653,0.11,175,195,30,45,1.82,0.25,R,rm)
    
#     r45=normalized_parameter_generation(19,4,0.38,0.09,180,225,75,90,1.6,0.15,R,br)
    
#     r6=normalized_parameter_generation(10,4,0.36,0.1,105,145,60,90,1.61,0.3,R,br)
    
#     rl7=normalized_parameter_generation(10.5,1.25,0.463,0.08,175,195,20,40,1.74,0.22,R,br)
    
#     r7=normalized_parameter_generation(16,5,0.27,0.06,-105,-30,30,45,1.45,0.17,R,rl7)
    
#     rl=normalized_parameter_generation(10,4,0.41,0.1,175,195,20,40,1.6,0.21,R,rl7)
    
#     r8=normalized_parameter_generation(12.5,1.5,0.296,0.073,195,255,45,60,1.51,0.17,R)
    
#     r910=normalized_parameter_generation(11,3.5,0.366,0.083,175,195,20,40,1.61,0.15,R,rl)
    
#     r9=normalized_parameter_generation(15,3.5,0.262,0.06,175,195,20,45,1.38,0.21,R,r910)
    
#     r10=normalized_parameter_generation(13,3.5,3.03,0.074,-30,30,0,45,1.45,0.16,R,r910)
    
#     r1=normalized_parameter_generation(13,3.5,0.33,0.06,180,270,135,180,1.5,0.22,R,ru)
    
#     r2=normalized_parameter_generation(11,3,0.31,0.061,120,180,75,100,1.48,0.16,R,ru)
    
#     r3=normalized_parameter_generation(12,3.75,0.35,0.096,225,270,90,120,1.61,0.18,R,ru)
    
#     r4=normalized_parameter_generation(12.5,4,0.27,0.07,150,180,60,90,1.4,0.16,R,r45)
    
#     r5=normalized_parameter_generation(14,4,0.29,0.06,195,225,60,90,1.47,0.17,R,r45)
   
    
#     lm=normalized_parameter_generation(50,5,0.7,0.11,-15,5,30,35,2.06,0.34,R)
    
#     lu=normalized_parameter_generation(13,3,0.58,0.18,-60,-15,85,105,1.92,0.3,R,lm)
    
#     ll6=normalized_parameter_generation(12.5,2.5,0.6,0.13,-15,5,30,45,1.97,0.32,R,lm)
    
#     l6=normalized_parameter_generation(10,2.8,0.41,0.15,55,105,50,90,1.71,0.22,R,ll6)
    
#     ll=normalized_parameter_generation(17,4,0.47,0.1,-15,5,30,45,1.76,0.15,R,ll6)
    
#     l8=normalized_parameter_generation(12.5,4,0.32,0.07,-75,5,45,60,1.57,0.15,R,ll)
    
#     l910=normalized_parameter_generation(10,3,0.42,0.1,-25,5,15,45,1.66,0.15,R,ll)
    
#     l9=normalized_parameter_generation(15,4.75,0.3,0.075,-35,0,20,45,1.48,0.21,R,l910)#cl=15
    
#     l10=normalized_parameter_generation(15,4.75,0.32,0.075,5,25,20,45,1.5,0.17,R,l910)#cl=15
    
#     l123=normalized_parameter_generation(8.5,1.5,0.454,0.125,-90,15,155,175,1.75,0.19,R,lu)
    
#     l12=normalized_parameter_generation(6,2.5,0.33,0.1,-45,20,155,180,1.56,0.37,R,l123)
    
#     l1=normalized_parameter_generation(13,3.5,0.263,0.08,60,150,120,180,1.38,0.188,R,l12)
    
#     l2=normalized_parameter_generation(12.5,3,0.225,0.06,150,250,150,180,1.27,0.24,R,l12)
    
#     l3=normalized_parameter_generation(10,3,0.33,0.09,-60,60,120,150,1.57,0.175,R,l123)
    
#     l45=normalized_parameter_generation(14,5,0.40,0.1,-60,-50,30,75,1.62,0.41,R,lu,)
    
#     l4=normalized_parameter_generation(12.5,5,0.264,0.05,-30,30,60,75,1.36,0.16,R,l45)
    
#     l5=normalized_parameter_generation(12.5,3.5,0.26,0.06,15,30,45,60,1.35,0.16,R,l45)


#     # ## One-D Tree generation

#     # In[7]:


#     def main_branch_generation(seed,index_matrix,branch,base=[0,0,0,0],label=60,vanish=1,bifurcate=1):
#         length=int(branch[0]*2+base[1]+branch[1]*0.5)
#         phi=branch[2]
#         theta=branch[3]
#         base_r=int(base[1])
#         x=np.zeros((length))
#         y=np.zeros((length))
#         z=np.zeros((length))
#         x1=x
#         y1=y
#         z1=z
#         line=np.zeros((length))
#         line1=line
#         prob_v=np.random.binomial(1,vanish,1)[0]
#         prob_b=np.random.binomial(1,bifurcate,1)[0]
#         for i in range (0,length):
#             x[i]=int((i)*np.sin(theta)*np.cos(phi))+seed[0]
#             y[i]=int((i)*np.sin(theta)*np.sin(phi))+seed[1]
#             z[i]=int((i)*np.cos(theta))+seed[2]
#             line[i]=label
#             index_matrix[int(x[i])+360,int(y[i])+360,int(z[i])]=line[i]
#             if prob_v==0:
#                 index_matrix[int(x[i])+360,int(y[i])+360,int(z[i])]=0
#         end=length-1
#     #     end=np.array([x[end],y[end],z[end]])
#     #     if prob_v==0:
#     #         end=seed
#     #     if prob_b==0:
#     #         theta1=theta+np.random.randint(15,30)/180*np.pi
#     #         for j in range (0,length):
#     #             x1[j]=int((base_r+j)*np.sin(theta1)*np.cos(phi))+seed[0]
#     #             y1[j]=int((base_r+j)*np.sin(theta1)*np.sin(phi))+seed[1]
#     #             z1[j]=int((base_r+j)*np.cos(theta1))+seed[2]
#     #             line1[j]=label
#     #             index_matrix[int(x1[j])+360,int(y1[j])+360,int(z1[j])]=line1[j]
#     #         x=np.hstack((x,x1))
#     #         y=np.hstack((y,y1))
#     #         z=np.hstack((z,z1))
#         info=np.array([(x[0],y[0],z[0]),(x[end],y[end],z[end])])
#         return index_matrix,info


#     # In[8]:


#     def s_branch_generation (index_matrix,f_branch,seed,label=100):
#         length_factor=np.random.normal(7,1,2)/10
#         radius_factor=np.random.normal(6.5,0.8,2)/10
#     #     radius_factor=np.array([0.5,0.5])
#         theta_1=f_branch[3]+np.random.randint(5,22)/180*np.pi
#         theta_2=f_branch[3]-np.random.randint(5,22)/180*np.pi
#         phi_1=np.random.randint(15,20)/180+f_branch[2]
#         phi_2=f_branch[2]-np.random.randint(10,20)/180
#         length_1=int(length_factor[0]*f_branch[0]*2)
#         length_2=int(length_factor[1]*f_branch[0]*2)

#         x=np.zeros((length_1))
#         y=np.zeros((length_1))
#         z=np.zeros((length_1))
#         x1=np.zeros((length_2))
#         y1=np.zeros((length_2))
#         z1=np.zeros((length_2))
#         for i in range (0,length_1):
#             x[i]=int((f_branch[1]+i)*np.sin(theta_1)*np.cos(phi_1))+seed[1,0]
#             y[i]=int((f_branch[1]+i)*np.sin(theta_1)*np.sin(phi_1))+seed[1,1]
#             z[i]=int((f_branch[1]+i)*np.cos(theta_1))+seed[1,2]

#             index_matrix[int(x[i])+360,int(y[i])+360,int(z[i])]=label

#         l=len(x)-1
#         s_branch=[(x[0],y[0],z[0]),(x[l],y[l],z[l])]



#         for j in range (0,length_2):
#             x1[j]=int((f_branch[1]+j)*np.sin(theta_2)*np.cos(phi_2))+seed[1,0]
#             y1[j]=int((f_branch[1]+j)*np.sin(theta_2)*np.sin(phi_2))+seed[1,1]
#             z1[j]=int((f_branch[1]+j)*np.cos(theta_2))+seed[1,2]

#             index_matrix[int(x1[j])+360,int(y1[j])+360,int(z1[j])]=label
#     #         index_matrix1[int(x1[j])+360,int(y1[j])+360,int(z1[j])]=label
#         l1=length_2-1
#         s1_branch=[(x1[0],y1[0],z1[0]),(x1[l1],y1[l1],z1[l1])]
#     #     x=np.hstack((x,x1))
#     #     y=np.hstack((y,y1))
#     #     z=np.hstack((z,z1))
#         radius=radius_factor*f_branch[1]
#     #     print (s1_branch)

#         ends=np.array([(length_1,radius[0],phi_1,theta_1,x[0],y[0],z[0],x[l],y[l],z[l]),(length_2,radius[1],phi_2,theta_2,x1[0],y1[0],z1[0],x1[l1],y1[l1],z1[l1])])
#         return index_matrix,ends


#     # In[9]:


#     def ss_branch_generation0 (index_matrix,f_branch,label=60):
#         length_factor=np.random.normal(7.5,0.3,2)/10
#         radius_factor=np.random.normal(6.5,0.8,2)/10

#     #     radius_factor=np.array([0.5,0.5])
#         theta_1=f_branch[3]+np.random.randint(5,22)/180*np.pi
#         theta_2=f_branch[3]-np.random.randint(5,22)/180*np.pi
#         phi_1=np.random.randint(15,20)/180+f_branch[2]
#         phi_2=f_branch[2]-np.random.randint(10,20)/180
#         length_1=int(length_factor[0]*f_branch[0]*2)
#         if length_1<1:
#             length_1=2
#         length_2=int(length_factor[1]*f_branch[0]*2)
#         if length_2<1:
#             length_2=2
#     #     print (length_1,length_2)
#         x=np.zeros((length_1))
#         y=np.zeros((length_1))
#         z=np.zeros((length_1))
#         x1=np.zeros((length_2))
#         y1=np.zeros((length_2))
#         z1=np.zeros((length_2))
#         for i in range (0,length_1):
#             x[i]=int((f_branch[1]+i)*np.sin(theta_1)*np.cos(phi_1))+f_branch[7]
#             y[i]=int((f_branch[1]+i)*np.sin(theta_1)*np.sin(phi_1))+f_branch[8]
#             z[i]=int((f_branch[1]+i)*np.cos(theta_1))+f_branch[9]

#             index_matrix[int(x[i])+360,int(y[i])+360,int(z[i])]=label

#         l=length_1-1
#         s_branch=[(x[0],y[0],z[0]),(x[l],y[l],z[l])]



#         for j in range (0,length_2):
#             x1[j]=int((f_branch[1]+j)*np.sin(theta_2)*np.cos(phi_2))+f_branch[7]
#             y1[j]=int((f_branch[1]+j)*np.sin(theta_2)*np.sin(phi_2))+f_branch[8]
#             z1[j]=int((f_branch[1]+j)*np.cos(theta_2))+f_branch[9]

#             index_matrix[int(x1[j])+360,int(y1[j])+360,int(z1[j])]=label

#         l1=length_2-1
#         s1_branch=[(x1[0],y1[0],z1[0]),(x1[l1],y1[l1],z1[l1])]
#     #     x=np.hstack((x,x1))
#     #     y=np.hstack((y,y1))
#     #     z=np.hstack((z,z1))
#         radius=radius_factor*f_branch[1]
#     #     print (s1_branch)
#     #     print (radius)
#         ends=np.array([(length_1,radius[0],phi_1,theta_1,x[0],y[0],z[0],x[l],y[l],z[l]),(length_2,radius[1],phi_2,theta_2,x1[0],y1[0],z1[0],x1[l1],y1[l1],z1[l1])])
#         return index_matrix,ends

#     def ss_branch_generation(index_matrix,ends):
#         f_branch_0=ends[0]
#     #     print(f_branch_0)
#         f_branch_1=ends[1]
#     #     print(f_branch_1)
#         index_matrix,ends1=ss_branch_generation0(index_matrix,f_branch_0)
#         index_matrix,ends2=ss_branch_generation0(index_matrix,f_branch_1)
#         ends=np.vstack((ends1,ends2))

#         return index_matrix,ends



#     # In[10]:


#     index_matrix_tree,trachea_i=main_branch_generation(seed,index_matrix_tree,trachea)
#     #rmb
#     index_matrix_tree,rm_i=main_branch_generation(trachea_i[1],index_matrix_tree,rm,trachea)
#     #rul
#     index_matrix_tree,ru_i=main_branch_generation(rm_i[1],index_matrix_tree,ru,rm)
#     #bronlnt
#     index_matrix_tree,br_i=main_branch_generation(rm_i[1],index_matrix_tree,br,rm)
#     #rb4+5
#     index_matrix_tree,r45_i=main_branch_generation(br_i[1],index_matrix_tree,r45,br)
#     #rb6
#     index_matrix_tree,r6_i=main_branch_generation(br_i[1],index_matrix_tree,r6,br)
#     #rll7
#     index_matrix_tree,rl7_i=main_branch_generation(br_i[1],index_matrix_tree,rl7,br)
#     #rb7(future needs a vanish factor)
#     index_matrix_tree,r7_i=main_branch_generation(rl7_i[1],index_matrix_tree,r7,rl7)
#     #rll
#     index_matrix_tree,rl_i=main_branch_generation(rl7_i[1],index_matrix_tree,rl7)
#     #rb8(needs bifurcation factor)
#     index_matrix_tree,r8_i=main_branch_generation(rl_i[1],index_matrix_tree,r8,rl)
#     #rb9+10(needs a vanish factor)
#     index_matrix_tree,r910_i=main_branch_generation(rl_i[1],index_matrix_tree,r910,rl)
#     #rb9
#     index_matrix_tree,r9_i=main_branch_generation(r910_i[1],index_matrix_tree,r9,r910)
#     #rb10
#     index_matrix_tree,r10_i=main_branch_generation(r910_i[1],index_matrix_tree,r10,r910)
#     #rb1
#     index_matrix_tree,r1_i=main_branch_generation(ru_i[1],index_matrix_tree,r1,ru)
#     #rb2
#     index_matrix_tree,r2_i=main_branch_generation(ru_i[1],index_matrix_tree,r2,ru)
#     #rb3
#     index_matrix_tree,r3_i=main_branch_generation(ru_i[1],index_matrix_tree,r3,ru)
#     #rb4
#     index_matrix_tree,r4_i=main_branch_generation(r45_i[1],index_matrix_tree,r4,r45)
#     #rb5
#     index_matrix_tree,r5_i=main_branch_generation(r45_i[1],index_matrix_tree,r5,r45)
#     #lmb
#     index_matrix_tree,lm_i=main_branch_generation(trachea_i[1],index_matrix_tree,lm,trachea)
#     #lul
#     index_matrix_tree,lu_i=main_branch_generation(lm_i[1],index_matrix_tree,lu,lm)
#     #llb6
#     index_matrix_tree,ll6_i=main_branch_generation(lm_i[1],index_matrix_tree,ll6,lm)
#     #lb6
#     index_matrix_tree,l6_i=main_branch_generation(ll6_i[1],index_matrix_tree,l6,ll6)
#     #llb
#     index_matrix_tree,ll_i=main_branch_generation(ll6_i[1],index_matrix_tree,ll,ll6)
#     #lb8
#     index_matrix_tree,l8_i=main_branch_generation(ll_i[1],index_matrix_tree,l8,ll)
#     #lb9+10
#     index_matrix_tree,l910_i=main_branch_generation(ll_i[1],index_matrix_tree,l910,ll)
#     #lb9
#     index_matrix_tree,l9_i=main_branch_generation(l910_i[1],index_matrix_tree,l9,l910)
#     #lb10
#     index_matrix_tree,l10_i=main_branch_generation(l910_i[1],index_matrix_tree,l10,l910)
#     #lb1+2+3
#     index_matrix_tree,l123_i=main_branch_generation(lu_i[1],index_matrix_tree,l123,lu)
#     #lb1+2
#     index_matrix_tree,l12_i=main_branch_generation(l123_i[1],index_matrix_tree,l12,l123)
#     #lb3
#     index_matrix_tree,l3_i=main_branch_generation(l123_i[1],index_matrix_tree,l3,l123)
#     #lb1
#     index_matrix_tree,l1_i=main_branch_generation(l12_i[1],index_matrix_tree,l1,l12)
#     #lb2
#     index_matrix_tree,l2_i=main_branch_generation(l12_i[1],index_matrix_tree,l2,l12)
#     #lb4+5
#     index_matrix_tree,l45_i=main_branch_generation(lu_i[1],index_matrix_tree,l45,lu)
#     #lb4
#     index_matrix_tree,l4_i=main_branch_generation(l45_i[1],index_matrix_tree,l4,l45)
#     #lb5
#     index_matrix_tree,l5_i=main_branch_generation(l45_i[1],index_matrix_tree,l5,l45)    


#     # In[11]:


#     index_matrix_tree,sr1=s_branch_generation(index_matrix_tree,r1,r1_i)
#     index_matrix_tree,sr2=s_branch_generation(index_matrix_tree,r2,r2_i)
#     index_matrix_tree,sr3=s_branch_generation(index_matrix_tree,r3,r3_i)
#     index_matrix_tree,sr4=s_branch_generation(index_matrix_tree,r4,r4_i)
#     index_matrix_tree,sr5=s_branch_generation(index_matrix_tree,r5,r5_i)
#     index_matrix_tree,sr6=s_branch_generation(index_matrix_tree,r6,r6_i)
#     index_matrix_tree,sr7=s_branch_generation(index_matrix_tree,r7,r7_i)
#     index_matrix_tree,sr8=s_branch_generation(index_matrix_tree,r8,r8_i)
#     index_matrix_tree,sr9=s_branch_generation(index_matrix_tree,r9,r9_i)
#     index_matrix_tree,sr10=s_branch_generation(index_matrix_tree,r10,r10_i)
#     index_matrix_tree,sl1=s_branch_generation(index_matrix_tree,l1,l1_i)
#     index_matrix_tree,sl2=s_branch_generation(index_matrix_tree,l2,l2_i)
#     index_matrix_tree,sl3=s_branch_generation(index_matrix_tree,l3,l3_i)
#     index_matrix_tree,sl4=s_branch_generation(index_matrix_tree,l4,l4_i)
#     index_matrix_tree,sl5=s_branch_generation(index_matrix_tree,l5,l5_i)
#     index_matrix_tree,sl6=s_branch_generation(index_matrix_tree,l6,l6_i)
#     index_matrix_tree,sl8=s_branch_generation(index_matrix_tree,l8,l8_i)
#     index_matrix_tree,sl9=s_branch_generation(index_matrix_tree,l9,l9_i)
#     index_matrix_tree,sl10=s_branch_generation(index_matrix_tree,l10,l10_i)


#     # In[12]:


#     index_matrix_tree,ssr1=ss_branch_generation(index_matrix_tree,sr1)
#     index_matrix_tree,ssr2=ss_branch_generation(index_matrix_tree,sr2)
#     index_matrix_tree,ssr3=ss_branch_generation(index_matrix_tree,sr3)
#     index_matrix_tree,ssr4=ss_branch_generation(index_matrix_tree,sr4)
#     index_matrix_tree,ssr5=ss_branch_generation(index_matrix_tree,sr5)
#     index_matrix_tree,ssr6=ss_branch_generation(index_matrix_tree,sr6)
#     index_matrix_tree,ssr7=ss_branch_generation(index_matrix_tree,sr7)
#     index_matrix_tree,ssr8=ss_branch_generation(index_matrix_tree,sr8)
#     index_matrix_tree,ssr9=ss_branch_generation(index_matrix_tree,sr9)
#     index_matrix_tree,ssr10=ss_branch_generation(index_matrix_tree,sr10)
#     index_matrix_tree,ssl1=ss_branch_generation(index_matrix_tree,sl1)
#     index_matrix_tree,ssl2=ss_branch_generation(index_matrix_tree,sl2)
#     index_matrix_tree,ssl3=ss_branch_generation(index_matrix_tree,sl3)
#     index_matrix_tree,ssl4=ss_branch_generation(index_matrix_tree,sl4)
#     index_matrix_tree,ssl5=ss_branch_generation(index_matrix_tree,sl5)
#     index_matrix_tree,ssl6=ss_branch_generation(index_matrix_tree,sl6)
#     index_matrix_tree,ssl8=ss_branch_generation(index_matrix_tree,sl8)
#     index_matrix_tree,ssl9=ss_branch_generation(index_matrix_tree,sl9)
#     index_matrix_tree,ssl10=ss_branch_generation(index_matrix_tree,sl10)



#     # In[13]:


# #     index_matrix1=np.copy(index_matrix)



#     # ## Airway Modeling

#     # In[14]:
# #     matrix0=index_matrix_generation()
# #     matrix1=index_matrix_generation()

#     def airway_modeling(index_matrix,info,branch,s_branch1,s_branch2,num_id=60):
#     #     start=time.time()
#         P=info[0]+[360,360,0]
#         Q=info[1]+[360,360,0]
#         AB = Q - P;
#         temp = AB / np.dot(AB,AB);
#         r1=branch[1]
#         r2=max(s_branch1[1],s_branch2[1])
#         rf=(r2-r1)

#         lmin=int(min(P[0],Q[0])-1.2*int(r1))
#         lmax=int(max(P[0],Q[0])+1.2*int(r1))
#         wmin=int(min(P[1],Q[1])-1.2*int(r1))
#         wmax=int(max(P[1],Q[1])+1.2*int(r1))
#         hmin=int(min(P[2],Q[2])-1*int(r1))
#         if hmin<0:
#             hmin=0
#         hmax=int(max(P[2],Q[2])+1*int(r1)+1)

#         x_range = np.sort(np.array([P[0], Q[0]]));
#         y_range = np.sort(np.array([P[1], Q[1]]));
#         z_range = np.sort(np.array([P[2], Q[2]]));
#         #for any point on line x^2+y^2+z^2=<r^2
#         for i in range(lmin,lmax):       
#             for j in range (wmin,wmax):
#                 for k in range(hmin,hmax):
#                     p = np.array([i, j, k])
#                     AP = p - P;
#                     BP = p - Q
#                     proj_point = P + np.dot(AP,AB) * temp;
#                     distance_s = (proj_point[0] - p[0])**2 + (proj_point[1] - p[1])**2 + (proj_point[2] - p[2])**2;
#                     distance_1_s = (P[0] - p[0])**2 + (P[1] - p[1])**2 + (P[2] - p[2])**2;
#                     distance_2_s = (Q[0] - p[0])**2 + (Q[1] - p[1])**2 + (Q[2] - p[2])**2;
#                     r=r1+rf*(np.dot(AP,AP)/np.dot(AB,AB))
#                     ri=r-2*branch[4]

#                     if distance_s <=r*r and index_matrix[i,j,k]==0 and (x_range[0] <= proj_point[0] and proj_point[0] <= x_range[1]) and (
#                                 y_range[0] <= proj_point[1] and proj_point[1] <= y_range[1]) and (
#                                         z_range[0] <= proj_point[2] and proj_point[2] <= z_range[1]) or distance_1_s<=r*r or distance_2_s<=r*r:
#                         if index_matrix[i,j,k]==0:


#                             index_matrix[i,j,k]=num_id
#                     if distance_s <=ri*ri and (x_range[0] <= proj_point[0] and proj_point[0] <= x_range[1]) and (
#                                 y_range[0] <= proj_point[1] and proj_point[1] <= y_range[1]) and (
#                                         z_range[0] <= proj_point[2] and proj_point[2] <= z_range[1]) or distance_1_s<=ri*ri or distance_2_s<=ri*ri:
#                         index_matrix[i,j,k]=255


#     #     end=time.time()
#     #     print (end-start,"s")
#         return index_matrix#,xx,yy,zz


#     # In[15]:


#     #np.array([(length_1,radius[0],phi_1,theta_1,x[0],y[0],z[0],x[l],y[l],z[l]),(length_2,radius[1],phi_2,theta_2,x1[0],y1[0],z1[0],x1[l1],y1[l1],z1[l1])])
#     def s_airway_modeling0(index_matrix,s_branch,num_id=100):
#     #     start=time.time()
#         P=np.array(s_branch)[4:7]+[360,360,0]
#         Q=np.array(s_branch)[7:10]+[360,360,0]
#         AB = Q - P;
#         temp = AB / np.dot(AB,AB);
#         r=s_branch[1]
#         ri=0.75*r




#         lmin=int(min(P[0],Q[0])-1.5*int(r))
#         lmax=int(max(P[0],Q[0])+1.5*int(r))
#         wmin=int(min(P[1],Q[1])-1.5*int(r))
#         wmax=int(max(P[1],Q[1])+1.5*int(r))
#         hmin=int(min(P[2],Q[2])-1.5*int(r))
#         if hmin<0:
#             hmin=0
#         hmax=int(max(P[2],Q[2])+1.5*int(r)+1)

#         x_range = np.sort(np.array([P[0], Q[0]]));
#         y_range = np.sort(np.array([P[1], Q[1]]));
#         z_range = np.sort(np.array([P[2], Q[2]]));
#         #for any point on line x^2+y^2+z^2=<r^2
#         for i in range(lmin,lmax):       
#             for j in range (wmin,wmax):
#                 for k in range(hmin,hmax):
#                     p = np.array([i, j, k])
#                     AP = p - P;
#                     BP = p - Q
#                     proj_point = P + np.dot(AP,AB) * temp;
#                     distance_s = (proj_point[0] - p[0])**2 + (proj_point[1] - p[1])**2 + (proj_point[2] - p[2])**2;
#                     distance_1_s = (P[0] - p[0])**2 + (P[1] - p[1])**2 + (P[2] - p[2])**2;
#                     distance_2_s = (Q[0] - p[0])**2 + (Q[1] - p[1])**2 + (Q[2] - p[2])**2;

                    

#     #                 if distance_s <=r*r or distance_t1<=r*r or distance_t2<=r*r and index_matrix[i,k,k]==0:
#                     if distance_s <=r*r and index_matrix[i,j,k]==0 and (x_range[0] <= proj_point[0] and proj_point[0] <= x_range[1]) and (
#                                 y_range[0] <= proj_point[1] and proj_point[1] <= y_range[1]) and (
#                                         z_range[0] <= proj_point[2] and proj_point[2] <= z_range[1]) or distance_1_s<=r*r or distance_2_s<=r*r:
#                         if index_matrix[i,j,k]==0:


#                             index_matrix[i,j,k]=num_id

#                     if distance_s <=ri*ri and (x_range[0] <= proj_point[0] and proj_point[0] <= x_range[1]) and (
#                                 y_range[0] <= proj_point[1] and proj_point[1] <= y_range[1]) and (
#                                         z_range[0] <= proj_point[2] and proj_point[2] <= z_range[1]) or distance_1_s<=ri*ri or distance_2_s<=ri*ri:
#                         index_matrix[i,j,k]=255
#     #     end=time.time()
#     #     print (end-start,"s")
#         return index_matrix#,xx,yy,zz

#     def s_airway_modeling(index_matrix,s_branch):
#         index_matrix=s_airway_modeling0(index_matrix,s_branch[0])
#         index_matrix=s_airway_modeling0(index_matrix,s_branch[1])
#         return index_matrix


#     # In[16]:


#     def ss_airway_modeling(index_matrix,ss_branch):
#         for i in range(0,4):
#             index_matrix=s_airway_modeling0(index_matrix,ss_branch[i])
#         return index_matrix


#     # ## Generating testing image

#     # In[17]:


#     def generating_test_image(index_matrix):
#         start=time.time()
#         print ("generating main branch")
#         index_matrix=airway_modeling(index_matrix,trachea_i,trachea,lm,rm)
#         index_matrix=airway_modeling(index_matrix,rm_i,rm,ru,br)
#         index_matrix=airway_modeling(index_matrix,ru_i,ru,r1,r2)
#         index_matrix=airway_modeling(index_matrix,br_i,br,r45,r6)
#         index_matrix=airway_modeling(index_matrix,r45_i,r45,r4,r5)
#         index_matrix=airway_modeling(index_matrix,r6_i,r6,rl7,rl7)
#         index_matrix=airway_modeling(index_matrix,rl7_i,rl7,r7,rl)
#         index_matrix=airway_modeling(index_matrix,rl_i,rl,r910,r910)
#         index_matrix=airway_modeling(index_matrix,r910_i,r910,r9,r10)
#         index_matrix=airway_modeling(index_matrix,r8_i,r8,sr8[0],sr8[1])
#         index_matrix=airway_modeling(index_matrix,r9_i,r9,sr9[0],sr9[1])
#         index_matrix=airway_modeling(index_matrix,r10_i,r10,sr10[0],sr10[1])
#         index_matrix=airway_modeling(index_matrix,r4_i,r4,sr4[0],sr4[1])
#         index_matrix=airway_modeling(index_matrix,r5_i,r5,sr5[0],sr5[1])
#         index_matrix=airway_modeling(index_matrix,r7_i,r7,sr7[0],sr7[1])
#         index_matrix=airway_modeling(index_matrix,r1_i,r1,sr1[0],sr1[1])
#         index_matrix=airway_modeling(index_matrix,r2_i,r2,sr2[0],sr2[1])
#         index_matrix=airway_modeling(index_matrix,r3_i,r3,sr3[0],sr3[1])
#         index_matrix=airway_modeling(index_matrix,lm_i,lm,lu,ll6)
#         index_matrix=airway_modeling(index_matrix,lu_i,lu,l123,ll6)
#         index_matrix=airway_modeling(index_matrix,ll6_i,ll6,l6,ll)
#         index_matrix=airway_modeling(index_matrix,l6_i,l6,sl6[0],sl6[1])
#         index_matrix=airway_modeling(index_matrix,ll_i,ll,l910,l8)
#         index_matrix=airway_modeling(index_matrix,l8_i,l8,sl8[0],sl8[1])
#         index_matrix=airway_modeling(index_matrix,l910_i,l910,l9,l10)
#         index_matrix=airway_modeling(index_matrix,l123_i,l123,l12,l3)
#         index_matrix=airway_modeling(index_matrix,l12_i,l12,l1,l2)
#         index_matrix=airway_modeling(index_matrix,l1_i,l1,sl1[0],sl1[1])
#         index_matrix=airway_modeling(index_matrix,l2_i,l2,sl2[0],sl2[1])
#         index_matrix=airway_modeling(index_matrix,l3_i,l3,sl3[0],sl3[1])
#         index_matrix=airway_modeling(index_matrix,l45_i,l45,l4,l5)
#         index_matrix=airway_modeling(index_matrix,l4_i,l4,sl4[0],sl4[1])
#         index_matrix=airway_modeling(index_matrix,l5_i,l5,sl5[0],sl5[1])
#         index_matrix=airway_modeling(index_matrix,l9_i,l9,sl9[0],sl9[1])
#         index_matrix=airway_modeling(index_matrix,l10_i,l10,sl10[0],sl10[1])

#         print ("generating son branch")
#         index_matrix=s_airway_modeling(index_matrix,sr1)
#         index_matrix=s_airway_modeling(index_matrix,sr2)
#         index_matrix=s_airway_modeling(index_matrix,sr3)
#         index_matrix=s_airway_modeling(index_matrix,sr4)
#         index_matrix=s_airway_modeling(index_matrix,sr5)
#         index_matrix=s_airway_modeling(index_matrix,sr6)
#         index_matrix=s_airway_modeling(index_matrix,sr7)
#         index_matrix=s_airway_modeling(index_matrix,sr8)
#         index_matrix=s_airway_modeling(index_matrix,sr9)
#         index_matrix=s_airway_modeling(index_matrix,sr10)
#         index_matrix=s_airway_modeling(index_matrix,sl1)
#         index_matrix=s_airway_modeling(index_matrix,sl2)
#         index_matrix=s_airway_modeling(index_matrix,sl3)
#         index_matrix=s_airway_modeling(index_matrix,sl4)
#         index_matrix=s_airway_modeling(index_matrix,sl5)
#         index_matrix=s_airway_modeling(index_matrix,sl6)
#         index_matrix=s_airway_modeling(index_matrix,sl8)
#         index_matrix=s_airway_modeling(index_matrix,sl9)
#         index_matrix=s_airway_modeling(index_matrix,sl10)

#         print("generating grandson branch")
#         index_matrix=ss_airway_modeling(index_matrix,ssr1)
#         index_matrix=ss_airway_modeling(index_matrix,ssr2)
#         index_matrix=ss_airway_modeling(index_matrix,ssr3)
#         index_matrix=ss_airway_modeling(index_matrix,ssr4)
#         index_matrix=ss_airway_modeling(index_matrix,ssr5)
#         index_matrix=ss_airway_modeling(index_matrix,ssr6)
#         index_matrix=ss_airway_modeling(index_matrix,ssr7)
#         index_matrix=ss_airway_modeling(index_matrix,ssr8)
#         index_matrix=ss_airway_modeling(index_matrix,ssr9)
#         index_matrix=ss_airway_modeling(index_matrix,ssr10)
#         index_matrix=ss_airway_modeling(index_matrix,ssl1)
#         index_matrix=ss_airway_modeling(index_matrix,ssl2)
#         index_matrix=ss_airway_modeling(index_matrix,ssl3)
#         index_matrix=ss_airway_modeling(index_matrix,ssl4)
#         index_matrix=ss_airway_modeling(index_matrix,ssl5)
#         index_matrix=ss_airway_modeling(index_matrix,ssl6)
#         index_matrix=ss_airway_modeling(index_matrix,ssl8)
#         index_matrix=ss_airway_modeling(index_matrix,ssl9)
#         index_matrix=ss_airway_modeling(index_matrix,ssl10)
#         print ("swaping axes")
#         index_matrix=np.array(index_matrix,dtype="f")
#         index_matrix=np.swapaxes(index_matrix,0,2).copy()
#         end=time.time()
#         print(end-start,'s')
#         return index_matrix
    
#     def generating_label_image(index_matrix):
#         start=time.time()
#         print ("generating main branch")
#         index_matrix=airway_modeling(index_matrix,trachea_i,trachea,lm,rm,2100)
#         index_matrix=airway_modeling(index_matrix,rm_i,rm,ru,br,400)
#         index_matrix=airway_modeling(index_matrix,ru_i,ru,r1,r2,2000)
#         index_matrix=airway_modeling(index_matrix,br_i,br,r45,r6,500)
#         index_matrix=airway_modeling(index_matrix,r45_i,r45,r4,r5,1900)
#         index_matrix=airway_modeling(index_matrix,r6_i,r6,rl7,rl7,600)
#         index_matrix=airway_modeling(index_matrix,rl7_i,rl7,r7,rl,1800)
#         index_matrix=airway_modeling(index_matrix,rl_i,rl,r910,r910,700)
#         index_matrix=airway_modeling(index_matrix,r910_i,r910,r9,r10,1700)
#         index_matrix=airway_modeling(index_matrix,r8_i,r8,sr8[0],sr8[1],800)
#         index_matrix=airway_modeling(index_matrix,r9_i,r9,sr9[0],sr9[1],1600)
#         index_matrix=airway_modeling(index_matrix,r10_i,r10,sr10[0],sr10[1],900)
#         index_matrix=airway_modeling(index_matrix,r4_i,r4,sr4[0],sr4[1],1500)
#         index_matrix=airway_modeling(index_matrix,r5_i,r5,sr5[0],sr5[1],1000)
#         index_matrix=airway_modeling(index_matrix,r7_i,r7,sr7[0],sr7[1],1400)
#         index_matrix=airway_modeling(index_matrix,r1_i,r1,sr1[0],sr1[1],1100)
#         index_matrix=airway_modeling(index_matrix,r2_i,r2,sr2[0],sr2[1],1300)
#         index_matrix=airway_modeling(index_matrix,r3_i,r3,sr3[0],sr3[1],1200)
#         index_matrix=airway_modeling(index_matrix,lm_i,lm,lu,ll6,350)
#         index_matrix=airway_modeling(index_matrix,lu_i,lu,l123,ll6,2150)
#         index_matrix=airway_modeling(index_matrix,ll6_i,ll6,l6,ll,450)
#         index_matrix=airway_modeling(index_matrix,l6_i,l6,sl6[0],sl6[1],2050)
#         index_matrix=airway_modeling(index_matrix,ll_i,ll,l910,l8,550)
#         index_matrix=airway_modeling(index_matrix,l8_i,l8,sl8[0],sl8[1],1950)
#         index_matrix=airway_modeling(index_matrix,l910_i,l910,l9,l10,650)
#         index_matrix=airway_modeling(index_matrix,l123_i,l123,l12,l3,1850)
#         index_matrix=airway_modeling(index_matrix,l12_i,l12,l1,l2,750)
#         index_matrix=airway_modeling(index_matrix,l1_i,l1,sl1[0],sl1[1],1750)
#         index_matrix=airway_modeling(index_matrix,l2_i,l2,sl2[0],sl2[1],850)
#         index_matrix=airway_modeling(index_matrix,l3_i,l3,sl3[0],sl3[1],1650)
#         index_matrix=airway_modeling(index_matrix,l45_i,l45,l4,l5,950)
#         index_matrix=airway_modeling(index_matrix,l4_i,l4,sl4[0],sl4[1],1550)
#         index_matrix=airway_modeling(index_matrix,l5_i,l5,sl5[0],sl5[1],1050)
#         index_matrix=airway_modeling(index_matrix,l9_i,l9,sl9[0],sl9[1],1450)
#         index_matrix=airway_modeling(index_matrix,l10_i,l10,sl10[0],sl10[1],1150)

#         print ("generating son branch")
#         index_matrix=s_airway_modeling(index_matrix,sr1)
#         index_matrix=s_airway_modeling(index_matrix,sr2)
#         index_matrix=s_airway_modeling(index_matrix,sr3)
#         index_matrix=s_airway_modeling(index_matrix,sr4)
#         index_matrix=s_airway_modeling(index_matrix,sr5)
#         index_matrix=s_airway_modeling(index_matrix,sr6)
#         index_matrix=s_airway_modeling(index_matrix,sr7)
#         index_matrix=s_airway_modeling(index_matrix,sr8)
#         index_matrix=s_airway_modeling(index_matrix,sr9)
#         index_matrix=s_airway_modeling(index_matrix,sr10)
#         index_matrix=s_airway_modeling(index_matrix,sl1)
#         index_matrix=s_airway_modeling(index_matrix,sl2)
#         index_matrix=s_airway_modeling(index_matrix,sl3)
#         index_matrix=s_airway_modeling(index_matrix,sl4)
#         index_matrix=s_airway_modeling(index_matrix,sl5)
#         index_matrix=s_airway_modeling(index_matrix,sl6)
#         index_matrix=s_airway_modeling(index_matrix,sl8)
#         index_matrix=s_airway_modeling(index_matrix,sl9)
#         index_matrix=s_airway_modeling(index_matrix,sl10)

#         print("generating grandson branch")
#         index_matrix=ss_airway_modeling(index_matrix,ssr1)
#         index_matrix=ss_airway_modeling(index_matrix,ssr2)
#         index_matrix=ss_airway_modeling(index_matrix,ssr3)
#         index_matrix=ss_airway_modeling(index_matrix,ssr4)
#         index_matrix=ss_airway_modeling(index_matrix,ssr5)
#         index_matrix=ss_airway_modeling(index_matrix,ssr6)
#         index_matrix=ss_airway_modeling(index_matrix,ssr7)
#         index_matrix=ss_airway_modeling(index_matrix,ssr8)
#         index_matrix=ss_airway_modeling(index_matrix,ssr9)
#         index_matrix=ss_airway_modeling(index_matrix,ssr10)
#         index_matrix=ss_airway_modeling(index_matrix,ssl1)
#         index_matrix=ss_airway_modeling(index_matrix,ssl2)
#         index_matrix=ss_airway_modeling(index_matrix,ssl3)
#         index_matrix=ss_airway_modeling(index_matrix,ssl4)
#         index_matrix=ss_airway_modeling(index_matrix,ssl5)
#         index_matrix=ss_airway_modeling(index_matrix,ssl6)
#         index_matrix=ss_airway_modeling(index_matrix,ssl8)
#         index_matrix=ss_airway_modeling(index_matrix,ssl9)
#         index_matrix=ss_airway_modeling(index_matrix,ssl10)
#         print ("swaping axes")
#         index_matrix=np.array(index_matrix,dtype="f")
#         index_matrix=np.swapaxes(index_matrix,0,2).copy()
#         end=time.time()
#         print(end-start,'s')
#         return index_matrix
    
# #     def image_test_generation(index_matrix):
# #         index_matrix=generating_test_image(index_matrix)
# #         print (np.amax(index_matrix))
# #         print ("generating test Image")
# #         image=itk.GetImageFromArray(index_matrix)
# #         image.SetSpacing([0.5,0.5,0.5])
# #         return image
# #     image_t=image_test_generation(np.zeros((720,720,768)))
#     def image_label_generation(index_matrix):
#         index_matrix=generating_label_image(index_matrix)
#         print (np.amax(index_matrix))
#         image=itk.GetImageFromArray(index_matrix)
#         image.SetSpacing([0.5,0.5,0.5])
#         return image
#     def flip_image(image):
#         PixelType=itk.F
#         ImageType=itk.Image[PixelType,3]
#         flipAxes=(False,False,True)

#         flipfilter=itk.FlipImageFilter[ImageType].New()
#         flipfilter.SetInput(image)
#         flipfilter.SetFlipAxes(flipAxes)
#         flipfilter.Update()
#         return flipfilter.GetOutput()
#     image_l=flip_image(image_label_generation(np.zeros((720,720,768))))
  


#     return image_l

# %% [markdown]
# ## ver 0.3
# angle succession from father branch

# %%
def test_ge(num_id):
    def index_matrix_generation():
        index_matrix=np.zeros((720,720,768))
        return index_matrix
    index_matrix_tree=index_matrix_generation()


    # In[3]:


    def seed_generation():
        #set starting seed at trechea
        mu = 6 #
        sigma = 2 
        rand_pos = np.random.normal(mu, sigma, 3)
        seed=np.array([int(rand_pos[0]),int(rand_pos[1])-20,80])
        return seed
    seed=seed_generation()


    # ## Main branch parameter generation

    # In[4]:


    def parameter_generation(cl_mean,cl_sig,r_mean,r_sig,phi_min,phi_max,theta_min,theta_max,wall_mean,wall_sig):
        cl=np.random.normal(cl_mean,cl_sig)
        if cl<0:
            cl=0
        r=np.random.normal(r_mean,r_sig)
    
        phi=np.random.randint(phi_min,phi_max)/180*np.pi
        theta=np.random.randint(theta_min,theta_max)/180*np.pi
        wall=np.random.normal(wall_mean,wall_sig)
        return np.array([cl,r,phi,theta,wall])


    # In[5]:


    def normalized_parameter_generation(cl_mean,cl_sig,rn_mean,rn_sig,phi_min,phi_max,theta_min,theta_max,wall_mean,wall_sig,Trachea_r,limit=[0,0]):
        cl=np.random.normal(cl_mean,cl_sig)
        if cl<0:
            cl=0
    #     if cl>=1.5*limit[0]:
    #         cl=1.5*limit[0]
        r=np.random.normal(rn_mean,rn_sig/1.2)*Trachea_r
        phi=np.random.randint(phi_min,phi_max)/180*np.pi
        theta=np.random.randint(theta_min,theta_max)/180*np.pi
        if limit[1] >0:
            r=min(limit[1],r)
        wall=np.random.normal(wall_mean,wall_sig)
        return np.array([cl,r,phi,theta,wall])


    # In[6]:


    trachea=parameter_generation(109,14,23.9,2.9,85,95,18,20,2.6,0.24)## radius needed and centerline length needed
    R=trachea[1]
    rm=normalized_parameter_generation(25.5,2.5,0.84,0.13,175,185,30,35,2.3,0.33,R)
    
    ru=normalized_parameter_generation(15,4,0.59,0.17,185,225,85,105,1.8,0.3,R,rm)
    
    br=normalized_parameter_generation(29,3,0.653,0.11,175,195,30,45,1.82,0.25,R,rm)
    
    r45=normalized_parameter_generation(19,4,0.38,0.09,180,225,75,90,1.6,0.15,R,br)
    
    r6=normalized_parameter_generation(10,4,0.36,0.1,105,145,60,90,1.61,0.3,R,br)
    
    rl7=normalized_parameter_generation(10.5,1.25,0.463,0.08,175,195,20,40,1.74,0.22,R,br)
    
    r7=normalized_parameter_generation(16,5,0.27,0.06,-105,-30,30,45,1.45,0.17,R,rl7)
    
    rl=normalized_parameter_generation(10,4,0.41,0.1,175,195,20,40,1.6,0.21,R,rl7)
    
    r8=normalized_parameter_generation(12.5,1.5,0.296,0.073,195,255,45,60,1.51,0.17,R)
    
    r910=normalized_parameter_generation(11,3.5,0.366,0.083,rl[2]/np.pi*180-5,rl[2]/np.pi*180+5,rl[3]/np.pi*180-5,rl[3]/np.pi*180+5,1.61,0.15,R,rl)
    
    r9=normalized_parameter_generation(15,3.5,0.262,0.06,r910[2]/np.pi*180-15,r910[2]/np.pi*180-7,r910[3]/np.pi*180-10,r910[3]/np.pi*180-7,1.38,0.21,R,r910)
    
    r10=normalized_parameter_generation(13,3.5,3.03,0.074,r910[2]/np.pi*180+7,r910[2]/np.pi*180+15,r910[3]/np.pi*180+7,r910[3]/np.pi*180+15,1.45,0.16,R,r910)
    
    r1=normalized_parameter_generation(13,3.5,0.33,0.06,180,270,135,180,1.5,0.22,R,ru)
    
    r2=normalized_parameter_generation(11,3,0.31,0.061,120,180,75,100,1.48,0.16,R,ru)
    
    r3=normalized_parameter_generation(12,3.75,0.35,0.096,225,270,90,120,1.61,0.18,R,ru)
    
    r4=normalized_parameter_generation(12.5,4,0.27,0.07,150,180,60,90,1.4,0.16,R,r45)
    
    r5=normalized_parameter_generation(14,4,0.29,0.06,195,225,60,90,1.47,0.17,R,r45)
   
    
    lm=normalized_parameter_generation(50,5,0.7,0.11,-15,5,30,35,2.06,0.34,R)
    
    lu=normalized_parameter_generation(13,3,0.58,0.18,-60,-15,85,105,1.92,0.3,R,lm)
    
    ll6=normalized_parameter_generation(12.5,2.5,0.6,0.13,-15,5,30,45,1.97,0.32,R,lm)
    
    l6=normalized_parameter_generation(10,2.8,0.41,0.15,55,105,50,90,1.71,0.22,R,ll6)
    
    ll=normalized_parameter_generation(17,4,0.47,0.1,-15,5,30,45,1.76,0.15,R,ll6)
    
    l8=normalized_parameter_generation(12.5,4,0.32,0.07,-75,5,45,60,1.57,0.15,R,ll)
    
    l910=normalized_parameter_generation(10,3,0.42,0.1,-25,5,15,45,1.66,0.15,R,ll)
    
    l9=normalized_parameter_generation(15,4.75,0.3,0.075,-35,0,20,45,1.48,0.21,R,l910)#cl=15
    
    l10=normalized_parameter_generation(15,4.75,0.32,0.075,5,25,20,45,1.5,0.17,R,l910)#cl=15
    
    l123=normalized_parameter_generation(8.5,1.5,0.454,0.125,-90,15,155,175,1.75,0.19,R,lu)
    
    l12=normalized_parameter_generation(6,2.5,0.33,0.1,-45,20,155,180,1.56,0.37,R,l123)
    
    l1=normalized_parameter_generation(13,3.5,0.263,0.08,60,150,120,180,1.38,0.188,R,l12)
    
    l2=normalized_parameter_generation(12.5,3,0.225,0.06,150,250,150,180,1.27,0.24,R,l12)
    
    l3=normalized_parameter_generation(10,3,0.33,0.09,-60,60,120,150,1.57,0.175,R,l123)
    
    l45=normalized_parameter_generation(12,3.5,0.40,0.1,-60,-50,60,90,1.62,0.41,R,lu,)
    
    l4=normalized_parameter_generation(12.5,3.5,0.264,0.05,l45[2]/np.pi*180-15,l45[2]/np.pi*180-7,l45[3]/np.pi*180-15,l45[3]/np.pi*180-7,1.36,0.16,R,l45)
    
    l5=normalized_parameter_generation(12.5,3.5,0.26,0.06,l45[2]/np.pi*180+7,l45[2]/np.pi*180+15,l45[3]/np.pi*180+7,l45[3]/np.pi*180+15,1.35,0.16,R,l45)
    print (l45,l4,l5)

    # ## One-D Tree generation

    # In[7]:


    def main_branch_generation(seed,index_matrix,branch,base=[0,0,0,0],label=60,vanish=1,bifurcate=1):
        length=int(branch[0]*2+base[1]+branch[1]*0.5)
        phi=branch[2]
        theta=branch[3]
        base_r=int(base[1])
        x=np.zeros((length))
        y=np.zeros((length))
        z=np.zeros((length))
        x1=x
        y1=y
        z1=z
        line=np.zeros((length))
        line1=line
        prob_v=np.random.binomial(1,vanish,1)[0]
        prob_b=np.random.binomial(1,bifurcate,1)[0]
        for i in range (0,length):
            x[i]=int((i)*np.sin(theta)*np.cos(phi))+seed[0]
            y[i]=int((i)*np.sin(theta)*np.sin(phi))+seed[1]
            z[i]=int((i)*np.cos(theta))+seed[2]
            line[i]=label
            index_matrix[int(x[i])+360,int(y[i])+360,int(z[i])]=line[i]
            if prob_v==0:
                index_matrix[int(x[i])+360,int(y[i])+360,int(z[i])]=0
        end=length-1
    #     end=np.array([x[end],y[end],z[end]])
    #     if prob_v==0:
    #         end=seed
    #     if prob_b==0:
    #         theta1=theta+np.random.randint(15,30)/180*np.pi
    #         for j in range (0,length):
    #             x1[j]=int((base_r+j)*np.sin(theta1)*np.cos(phi))+seed[0]
    #             y1[j]=int((base_r+j)*np.sin(theta1)*np.sin(phi))+seed[1]
    #             z1[j]=int((base_r+j)*np.cos(theta1))+seed[2]
    #             line1[j]=label
    #             index_matrix[int(x1[j])+360,int(y1[j])+360,int(z1[j])]=line1[j]
    #         x=np.hstack((x,x1))
    #         y=np.hstack((y,y1))
    #         z=np.hstack((z,z1))
        info=np.array([(x[0],y[0],z[0]),(x[end],y[end],z[end])])
        return index_matrix,info


    # In[8]:


    def s_branch_generation (index_matrix,f_branch,seed,label=100):
        length_factor=np.random.normal(7,1,2)/10
        radius_factor=np.random.normal(6.5,0.8,2)/10
    #     radius_factor=np.array([0.5,0.5])
        theta_1=f_branch[3]+np.random.randint(5,22)/180*np.pi
        theta_2=f_branch[3]-np.random.randint(5,22)/180*np.pi
        phi_1=np.random.randint(15,20)/180+f_branch[2]
        phi_2=f_branch[2]-np.random.randint(10,20)/180
        length_1=int(length_factor[0]*f_branch[0]*2)
        length_2=int(length_factor[1]*f_branch[0]*2)

        x=np.zeros((length_1))
        y=np.zeros((length_1))
        z=np.zeros((length_1))
        x1=np.zeros((length_2))
        y1=np.zeros((length_2))
        z1=np.zeros((length_2))
        for i in range (0,length_1):
            x[i]=int((f_branch[1]+i)*np.sin(theta_1)*np.cos(phi_1))+seed[1,0]
            y[i]=int((f_branch[1]+i)*np.sin(theta_1)*np.sin(phi_1))+seed[1,1]
            z[i]=int((f_branch[1]+i)*np.cos(theta_1))+seed[1,2]

            index_matrix[int(x[i])+360,int(y[i])+360,int(z[i])]=label

        l=len(x)-1
        s_branch=[(x[0],y[0],z[0]),(x[l],y[l],z[l])]



        for j in range (0,length_2):
            x1[j]=int((f_branch[1]+j)*np.sin(theta_2)*np.cos(phi_2))+seed[1,0]
            y1[j]=int((f_branch[1]+j)*np.sin(theta_2)*np.sin(phi_2))+seed[1,1]
            z1[j]=int((f_branch[1]+j)*np.cos(theta_2))+seed[1,2]

            index_matrix[int(x1[j])+360,int(y1[j])+360,int(z1[j])]=label
    #         index_matrix1[int(x1[j])+360,int(y1[j])+360,int(z1[j])]=label
        l1=length_2-1
        s1_branch=[(x1[0],y1[0],z1[0]),(x1[l1],y1[l1],z1[l1])]
    #     x=np.hstack((x,x1))
    #     y=np.hstack((y,y1))
    #     z=np.hstack((z,z1))
        radius=radius_factor*f_branch[1]
    #     print (s1_branch)

        ends=np.array([(length_1,radius[0],phi_1,theta_1,x[0],y[0],z[0],x[l],y[l],z[l]),(length_2,radius[1],phi_2,theta_2,x1[0],y1[0],z1[0],x1[l1],y1[l1],z1[l1])])
        return index_matrix,ends


    # In[9]:


    def ss_branch_generation0 (index_matrix,f_branch,label=60):
        length_factor=np.random.normal(7.5,0.3,2)/10
        radius_factor=np.random.normal(6.5,0.8,2)/10

    #     radius_factor=np.array([0.5,0.5])
        theta_1=f_branch[3]+np.random.randint(5,22)/180*np.pi
        theta_2=f_branch[3]-np.random.randint(5,22)/180*np.pi
        phi_1=np.random.randint(15,20)/180+f_branch[2]
        phi_2=f_branch[2]-np.random.randint(10,20)/180
        length_1=int(length_factor[0]*f_branch[0]*2)
        if length_1<1:
            length_1=2
        length_2=int(length_factor[1]*f_branch[0]*2)
        if length_2<1:
            length_2=2
    #     print (length_1,length_2)
        x=np.zeros((length_1))
        y=np.zeros((length_1))
        z=np.zeros((length_1))
        x1=np.zeros((length_2))
        y1=np.zeros((length_2))
        z1=np.zeros((length_2))
        for i in range (0,length_1):
            x[i]=int((f_branch[1]+i)*np.sin(theta_1)*np.cos(phi_1))+f_branch[7]
            y[i]=int((f_branch[1]+i)*np.sin(theta_1)*np.sin(phi_1))+f_branch[8]
            z[i]=int((f_branch[1]+i)*np.cos(theta_1))+f_branch[9]

            index_matrix[int(x[i])+360,int(y[i])+360,int(z[i])]=label

        l=length_1-1
        s_branch=[(x[0],y[0],z[0]),(x[l],y[l],z[l])]



        for j in range (0,length_2):
            x1[j]=int((f_branch[1]+j)*np.sin(theta_2)*np.cos(phi_2))+f_branch[7]
            y1[j]=int((f_branch[1]+j)*np.sin(theta_2)*np.sin(phi_2))+f_branch[8]
            z1[j]=int((f_branch[1]+j)*np.cos(theta_2))+f_branch[9]

            index_matrix[int(x1[j])+360,int(y1[j])+360,int(z1[j])]=label

        l1=length_2-1
        s1_branch=[(x1[0],y1[0],z1[0]),(x1[l1],y1[l1],z1[l1])]
    #     x=np.hstack((x,x1))
    #     y=np.hstack((y,y1))
    #     z=np.hstack((z,z1))
        radius=radius_factor*f_branch[1]
    #     print (s1_branch)
    #     print (radius)
        ends=np.array([(length_1,radius[0],phi_1,theta_1,x[0],y[0],z[0],x[l],y[l],z[l]),(length_2,radius[1],phi_2,theta_2,x1[0],y1[0],z1[0],x1[l1],y1[l1],z1[l1])])
        return index_matrix,ends

    def ss_branch_generation(index_matrix,ends):
        f_branch_0=ends[0]
    #     print(f_branch_0)
        f_branch_1=ends[1]
    #     print(f_branch_1)
        index_matrix,ends1=ss_branch_generation0(index_matrix,f_branch_0)
        index_matrix,ends2=ss_branch_generation0(index_matrix,f_branch_1)
        ends=np.vstack((ends1,ends2))

        return index_matrix,ends



    # In[10]:


    index_matrix_tree,trachea_i=main_branch_generation(seed,index_matrix_tree,trachea)
    #rmb
    index_matrix_tree,rm_i=main_branch_generation(trachea_i[1],index_matrix_tree,rm,trachea)
    #rul
    index_matrix_tree,ru_i=main_branch_generation(rm_i[1],index_matrix_tree,ru,rm)
    #bronlnt
    index_matrix_tree,br_i=main_branch_generation(rm_i[1],index_matrix_tree,br,rm)
    #rb4+5
    index_matrix_tree,r45_i=main_branch_generation(br_i[1],index_matrix_tree,r45,br)
    #rb6
    index_matrix_tree,r6_i=main_branch_generation(br_i[1],index_matrix_tree,r6,br)
    #rll7
    index_matrix_tree,rl7_i=main_branch_generation(br_i[1],index_matrix_tree,rl7,br)
    #rb7(future needs a vanish factor)
    index_matrix_tree,r7_i=main_branch_generation(rl7_i[1],index_matrix_tree,r7,rl7)
    #rll
    index_matrix_tree,rl_i=main_branch_generation(rl7_i[1],index_matrix_tree,rl7)
    #rb8(needs bifurcation factor)
    index_matrix_tree,r8_i=main_branch_generation(rl_i[1],index_matrix_tree,r8,rl)
    #rb9+10(needs a vanish factor)
    index_matrix_tree,r910_i=main_branch_generation(rl_i[1],index_matrix_tree,r910,rl)
    #rb9
    index_matrix_tree,r9_i=main_branch_generation(r910_i[1],index_matrix_tree,r9,r910)
    #rb10
    index_matrix_tree,r10_i=main_branch_generation(r910_i[1],index_matrix_tree,r10,r910)
    #rb1
    index_matrix_tree,r1_i=main_branch_generation(ru_i[1],index_matrix_tree,r1,ru)
    #rb2
    index_matrix_tree,r2_i=main_branch_generation(ru_i[1],index_matrix_tree,r2,ru)
    #rb3
    index_matrix_tree,r3_i=main_branch_generation(ru_i[1],index_matrix_tree,r3,ru)
    #rb4
    index_matrix_tree,r4_i=main_branch_generation(r45_i[1],index_matrix_tree,r4,r45)
    #rb5
    index_matrix_tree,r5_i=main_branch_generation(r45_i[1],index_matrix_tree,r5,r45)
    #lmb
    index_matrix_tree,lm_i=main_branch_generation(trachea_i[1],index_matrix_tree,lm,trachea)
    #lul
    index_matrix_tree,lu_i=main_branch_generation(lm_i[1],index_matrix_tree,lu,lm)
    #llb6
    index_matrix_tree,ll6_i=main_branch_generation(lm_i[1],index_matrix_tree,ll6,lm)
    #lb6
    index_matrix_tree,l6_i=main_branch_generation(ll6_i[1],index_matrix_tree,l6,ll6)
    #llb
    index_matrix_tree,ll_i=main_branch_generation(ll6_i[1],index_matrix_tree,ll,ll6)
    #lb8
    index_matrix_tree,l8_i=main_branch_generation(ll_i[1],index_matrix_tree,l8,ll)
    #lb9+10
    index_matrix_tree,l910_i=main_branch_generation(ll_i[1],index_matrix_tree,l910,ll)
    #lb9
    index_matrix_tree,l9_i=main_branch_generation(l910_i[1],index_matrix_tree,l9,l910)
    #lb10
    index_matrix_tree,l10_i=main_branch_generation(l910_i[1],index_matrix_tree,l10,l910)
    #lb1+2+3
    index_matrix_tree,l123_i=main_branch_generation(lu_i[1],index_matrix_tree,l123,lu)
    #lb1+2
    index_matrix_tree,l12_i=main_branch_generation(l123_i[1],index_matrix_tree,l12,l123)
    #lb3
    index_matrix_tree,l3_i=main_branch_generation(l123_i[1],index_matrix_tree,l3,l123)
    #lb1
    index_matrix_tree,l1_i=main_branch_generation(l12_i[1],index_matrix_tree,l1,l12)
    #lb2
    index_matrix_tree,l2_i=main_branch_generation(l12_i[1],index_matrix_tree,l2,l12)
    #lb4+5
    index_matrix_tree,l45_i=main_branch_generation(lu_i[1],index_matrix_tree,l45,lu)
    #lb4
    index_matrix_tree,l4_i=main_branch_generation(l45_i[1],index_matrix_tree,l4,l45)
    #lb5
    index_matrix_tree,l5_i=main_branch_generation(l45_i[1],index_matrix_tree,l5,l45)    


    # In[11]:


    index_matrix_tree,sr1=s_branch_generation(index_matrix_tree,r1,r1_i)
    index_matrix_tree,sr2=s_branch_generation(index_matrix_tree,r2,r2_i)
    index_matrix_tree,sr3=s_branch_generation(index_matrix_tree,r3,r3_i)
    index_matrix_tree,sr4=s_branch_generation(index_matrix_tree,r4,r4_i)
    index_matrix_tree,sr5=s_branch_generation(index_matrix_tree,r5,r5_i)
    index_matrix_tree,sr6=s_branch_generation(index_matrix_tree,r6,r6_i)
    index_matrix_tree,sr7=s_branch_generation(index_matrix_tree,r7,r7_i)
    index_matrix_tree,sr8=s_branch_generation(index_matrix_tree,r8,r8_i)
    index_matrix_tree,sr9=s_branch_generation(index_matrix_tree,r9,r9_i)
    index_matrix_tree,sr10=s_branch_generation(index_matrix_tree,r10,r10_i)
    index_matrix_tree,sl1=s_branch_generation(index_matrix_tree,l1,l1_i)
    index_matrix_tree,sl2=s_branch_generation(index_matrix_tree,l2,l2_i)
    index_matrix_tree,sl3=s_branch_generation(index_matrix_tree,l3,l3_i)
    index_matrix_tree,sl4=s_branch_generation(index_matrix_tree,l4,l4_i)
    index_matrix_tree,sl5=s_branch_generation(index_matrix_tree,l5,l5_i)
    index_matrix_tree,sl6=s_branch_generation(index_matrix_tree,l6,l6_i)
    index_matrix_tree,sl8=s_branch_generation(index_matrix_tree,l8,l8_i)
    index_matrix_tree,sl9=s_branch_generation(index_matrix_tree,l9,l9_i)
    index_matrix_tree,sl10=s_branch_generation(index_matrix_tree,l10,l10_i)


    # In[12]:


    index_matrix_tree,ssr1=ss_branch_generation(index_matrix_tree,sr1)
    index_matrix_tree,ssr2=ss_branch_generation(index_matrix_tree,sr2)
    index_matrix_tree,ssr3=ss_branch_generation(index_matrix_tree,sr3)
    index_matrix_tree,ssr4=ss_branch_generation(index_matrix_tree,sr4)
    index_matrix_tree,ssr5=ss_branch_generation(index_matrix_tree,sr5)
    index_matrix_tree,ssr6=ss_branch_generation(index_matrix_tree,sr6)
    index_matrix_tree,ssr7=ss_branch_generation(index_matrix_tree,sr7)
    index_matrix_tree,ssr8=ss_branch_generation(index_matrix_tree,sr8)
    index_matrix_tree,ssr9=ss_branch_generation(index_matrix_tree,sr9)
    index_matrix_tree,ssr10=ss_branch_generation(index_matrix_tree,sr10)
    index_matrix_tree,ssl1=ss_branch_generation(index_matrix_tree,sl1)
    index_matrix_tree,ssl2=ss_branch_generation(index_matrix_tree,sl2)
    index_matrix_tree,ssl3=ss_branch_generation(index_matrix_tree,sl3)
    index_matrix_tree,ssl4=ss_branch_generation(index_matrix_tree,sl4)
    index_matrix_tree,ssl5=ss_branch_generation(index_matrix_tree,sl5)
    index_matrix_tree,ssl6=ss_branch_generation(index_matrix_tree,sl6)
    index_matrix_tree,ssl8=ss_branch_generation(index_matrix_tree,sl8)
    index_matrix_tree,ssl9=ss_branch_generation(index_matrix_tree,sl9)
    index_matrix_tree,ssl10=ss_branch_generation(index_matrix_tree,sl10)



    # In[13]:


#     index_matrix1=np.copy(index_matrix)



    # ## Airway Modeling

    # In[14]:
#     matrix0=index_matrix_generation()
#     matrix1=index_matrix_generation()

    def airway_modeling(index_matrix,info,branch,s_branch1,s_branch2,num_id=60):
    #     start=time.time()
        P=info[0]+[360,360,0]
        Q=info[1]+[360,360,0]
        AB = Q - P;
        temp = AB / np.dot(AB,AB);
        r1=branch[1]
        r2=max(s_branch1[1],s_branch2[1])
        rf=(r2-r1)

        lmin=int(min(P[0],Q[0])-1.2*int(r1))
        lmax=int(max(P[0],Q[0])+1.2*int(r1))
        wmin=int(min(P[1],Q[1])-1.2*int(r1))
        wmax=int(max(P[1],Q[1])+1.2*int(r1))
        hmin=int(min(P[2],Q[2])-1*int(r1))
        if hmin<0:
            hmin=0
        hmax=int(max(P[2],Q[2])+1*int(r1)+1)

        x_range = np.sort(np.array([P[0], Q[0]]));
        y_range = np.sort(np.array([P[1], Q[1]]));
        z_range = np.sort(np.array([P[2], Q[2]]));
        #for any point on line x^2+y^2+z^2=<r^2
        for i in range(lmin,lmax):       
            for j in range (wmin,wmax):
                for k in range(hmin,hmax):
                    p = np.array([i, j, k])
                    AP = p - P;
                    BP = p - Q
                    proj_point = P + np.dot(AP,AB) * temp;
                    distance_s = (proj_point[0] - p[0])**2 + (proj_point[1] - p[1])**2 + (proj_point[2] - p[2])**2;
                    distance_1_s = (P[0] - p[0])**2 + (P[1] - p[1])**2 + (P[2] - p[2])**2;
                    distance_2_s = (Q[0] - p[0])**2 + (Q[1] - p[1])**2 + (Q[2] - p[2])**2;
                    r=r1+rf*(np.dot(AP,AP)/np.dot(AB,AB))
                    ri=r-2*branch[4]

                    if distance_s <=r*r and index_matrix[i,j,k]==0 and (x_range[0] <= proj_point[0] and proj_point[0] <= x_range[1]) and (
                                y_range[0] <= proj_point[1] and proj_point[1] <= y_range[1]) and (
                                        z_range[0] <= proj_point[2] and proj_point[2] <= z_range[1]) or distance_1_s<=r*r or distance_2_s<=r*r:
                        if index_matrix[i,j,k]==0:


                            index_matrix[i,j,k]=num_id
                    if distance_s <=ri*ri and (x_range[0] <= proj_point[0] and proj_point[0] <= x_range[1]) and (
                                y_range[0] <= proj_point[1] and proj_point[1] <= y_range[1]) and (
                                        z_range[0] <= proj_point[2] and proj_point[2] <= z_range[1]) or distance_1_s<=ri*ri or distance_2_s<=ri*ri:
                        index_matrix[i,j,k]=255


    #     end=time.time()
    #     print (end-start,"s")
        return index_matrix#,xx,yy,zz


    # In[15]:


    #np.array([(length_1,radius[0],phi_1,theta_1,x[0],y[0],z[0],x[l],y[l],z[l]),(length_2,radius[1],phi_2,theta_2,x1[0],y1[0],z1[0],x1[l1],y1[l1],z1[l1])])
    def s_airway_modeling0(index_matrix,s_branch,num_id=100):
    #     start=time.time()
        P=np.array(s_branch)[4:7]+[360,360,0]
        Q=np.array(s_branch)[7:10]+[360,360,0]
        AB = Q - P;
        temp = AB / np.dot(AB,AB);
        r=s_branch[1]
        ri=0.75*r




        lmin=int(min(P[0],Q[0])-1.5*int(r))
        lmax=int(max(P[0],Q[0])+1.5*int(r))
        wmin=int(min(P[1],Q[1])-1.5*int(r))
        wmax=int(max(P[1],Q[1])+1.5*int(r))
        hmin=int(min(P[2],Q[2])-1.5*int(r))
        if hmin<0:
            hmin=0
        hmax=int(max(P[2],Q[2])+1.5*int(r)+1)

        x_range = np.sort(np.array([P[0], Q[0]]));
        y_range = np.sort(np.array([P[1], Q[1]]));
        z_range = np.sort(np.array([P[2], Q[2]]));
        #for any point on line x^2+y^2+z^2=<r^2
        for i in range(lmin,lmax):       
            for j in range (wmin,wmax):
                for k in range(hmin,hmax):
                    p = np.array([i, j, k])
                    AP = p - P;
                    BP = p - Q
                    proj_point = P + np.dot(AP,AB) * temp;
                    distance_s = (proj_point[0] - p[0])**2 + (proj_point[1] - p[1])**2 + (proj_point[2] - p[2])**2;
                    distance_1_s = (P[0] - p[0])**2 + (P[1] - p[1])**2 + (P[2] - p[2])**2;
                    distance_2_s = (Q[0] - p[0])**2 + (Q[1] - p[1])**2 + (Q[2] - p[2])**2;

                    

    #                 if distance_s <=r*r or distance_t1<=r*r or distance_t2<=r*r and index_matrix[i,k,k]==0:
                    if distance_s <=r*r and index_matrix[i,j,k]==0 and (x_range[0] <= proj_point[0] and proj_point[0] <= x_range[1]) and (
                                y_range[0] <= proj_point[1] and proj_point[1] <= y_range[1]) and (
                                        z_range[0] <= proj_point[2] and proj_point[2] <= z_range[1]) or distance_1_s<=r*r or distance_2_s<=r*r:
                        if index_matrix[i,j,k]==0:


                            index_matrix[i,j,k]=num_id

                    if distance_s <=ri*ri and (x_range[0] <= proj_point[0] and proj_point[0] <= x_range[1]) and (
                                y_range[0] <= proj_point[1] and proj_point[1] <= y_range[1]) and (
                                        z_range[0] <= proj_point[2] and proj_point[2] <= z_range[1]) or distance_1_s<=ri*ri or distance_2_s<=ri*ri:
                        index_matrix[i,j,k]=255
    #     end=time.time()
    #     print (end-start,"s")
        return index_matrix#,xx,yy,zz

    def s_airway_modeling(index_matrix,s_branch):
        index_matrix=s_airway_modeling0(index_matrix,s_branch[0])
        index_matrix=s_airway_modeling0(index_matrix,s_branch[1])
        return index_matrix


    # In[16]:


    def ss_airway_modeling(index_matrix,ss_branch):
        for i in range(0,4):
            index_matrix=s_airway_modeling0(index_matrix,ss_branch[i])
        return index_matrix


    # ## Generating testing image

    # In[17]:


    def generating_test_image(index_matrix):
        start=time.time()
        print ("generating main branch")
        index_matrix=airway_modeling(index_matrix,trachea_i,trachea,lm,rm)
        index_matrix=airway_modeling(index_matrix,rm_i,rm,ru,br)
        index_matrix=airway_modeling(index_matrix,ru_i,ru,r1,r2)
        index_matrix=airway_modeling(index_matrix,br_i,br,r45,r6)
        index_matrix=airway_modeling(index_matrix,r45_i,r45,r4,r5)
        index_matrix=airway_modeling(index_matrix,r6_i,r6,rl7,rl7)
        index_matrix=airway_modeling(index_matrix,rl7_i,rl7,r7,rl)
        index_matrix=airway_modeling(index_matrix,rl_i,rl,r910,r910)
        index_matrix=airway_modeling(index_matrix,r910_i,r910,r9,r10)
        index_matrix=airway_modeling(index_matrix,r8_i,r8,sr8[0],sr8[1])
        index_matrix=airway_modeling(index_matrix,r9_i,r9,sr9[0],sr9[1])
        index_matrix=airway_modeling(index_matrix,r10_i,r10,sr10[0],sr10[1])
        index_matrix=airway_modeling(index_matrix,r4_i,r4,sr4[0],sr4[1])
        index_matrix=airway_modeling(index_matrix,r5_i,r5,sr5[0],sr5[1])
        index_matrix=airway_modeling(index_matrix,r7_i,r7,sr7[0],sr7[1])
        index_matrix=airway_modeling(index_matrix,r1_i,r1,sr1[0],sr1[1])
        index_matrix=airway_modeling(index_matrix,r2_i,r2,sr2[0],sr2[1])
        index_matrix=airway_modeling(index_matrix,r3_i,r3,sr3[0],sr3[1])
        index_matrix=airway_modeling(index_matrix,lm_i,lm,lu,ll6)
        index_matrix=airway_modeling(index_matrix,lu_i,lu,l123,ll6)
        index_matrix=airway_modeling(index_matrix,ll6_i,ll6,l6,ll)
        index_matrix=airway_modeling(index_matrix,l6_i,l6,sl6[0],sl6[1])
        index_matrix=airway_modeling(index_matrix,ll_i,ll,l910,l8)
        index_matrix=airway_modeling(index_matrix,l8_i,l8,sl8[0],sl8[1])
        index_matrix=airway_modeling(index_matrix,l910_i,l910,l9,l10)
        index_matrix=airway_modeling(index_matrix,l123_i,l123,l12,l3)
        index_matrix=airway_modeling(index_matrix,l12_i,l12,l1,l2)
        index_matrix=airway_modeling(index_matrix,l1_i,l1,sl1[0],sl1[1])
        index_matrix=airway_modeling(index_matrix,l2_i,l2,sl2[0],sl2[1])
        index_matrix=airway_modeling(index_matrix,l3_i,l3,sl3[0],sl3[1])
        index_matrix=airway_modeling(index_matrix,l45_i,l45,l4,l5)
        index_matrix=airway_modeling(index_matrix,l4_i,l4,sl4[0],sl4[1])
        index_matrix=airway_modeling(index_matrix,l5_i,l5,sl5[0],sl5[1])
        index_matrix=airway_modeling(index_matrix,l9_i,l9,sl9[0],sl9[1])
        index_matrix=airway_modeling(index_matrix,l10_i,l10,sl10[0],sl10[1])

        print ("generating son branch")
        index_matrix=s_airway_modeling(index_matrix,sr1)
        index_matrix=s_airway_modeling(index_matrix,sr2)
        index_matrix=s_airway_modeling(index_matrix,sr3)
        index_matrix=s_airway_modeling(index_matrix,sr4)
        index_matrix=s_airway_modeling(index_matrix,sr5)
        index_matrix=s_airway_modeling(index_matrix,sr6)
        index_matrix=s_airway_modeling(index_matrix,sr7)
        index_matrix=s_airway_modeling(index_matrix,sr8)
        index_matrix=s_airway_modeling(index_matrix,sr9)
        index_matrix=s_airway_modeling(index_matrix,sr10)
        index_matrix=s_airway_modeling(index_matrix,sl1)
        index_matrix=s_airway_modeling(index_matrix,sl2)
        index_matrix=s_airway_modeling(index_matrix,sl3)
        index_matrix=s_airway_modeling(index_matrix,sl4)
        index_matrix=s_airway_modeling(index_matrix,sl5)
        index_matrix=s_airway_modeling(index_matrix,sl6)
        index_matrix=s_airway_modeling(index_matrix,sl8)
        index_matrix=s_airway_modeling(index_matrix,sl9)
        index_matrix=s_airway_modeling(index_matrix,sl10)

        print("generating grandson branch")
        index_matrix=ss_airway_modeling(index_matrix,ssr1)
        index_matrix=ss_airway_modeling(index_matrix,ssr2)
        index_matrix=ss_airway_modeling(index_matrix,ssr3)
        index_matrix=ss_airway_modeling(index_matrix,ssr4)
        index_matrix=ss_airway_modeling(index_matrix,ssr5)
        index_matrix=ss_airway_modeling(index_matrix,ssr6)
        index_matrix=ss_airway_modeling(index_matrix,ssr7)
        index_matrix=ss_airway_modeling(index_matrix,ssr8)
        index_matrix=ss_airway_modeling(index_matrix,ssr9)
        index_matrix=ss_airway_modeling(index_matrix,ssr10)
        index_matrix=ss_airway_modeling(index_matrix,ssl1)
        index_matrix=ss_airway_modeling(index_matrix,ssl2)
        index_matrix=ss_airway_modeling(index_matrix,ssl3)
        index_matrix=ss_airway_modeling(index_matrix,ssl4)
        index_matrix=ss_airway_modeling(index_matrix,ssl5)
        index_matrix=ss_airway_modeling(index_matrix,ssl6)
        index_matrix=ss_airway_modeling(index_matrix,ssl8)
        index_matrix=ss_airway_modeling(index_matrix,ssl9)
        index_matrix=ss_airway_modeling(index_matrix,ssl10)
        print ("swaping axes")
        index_matrix=np.array(index_matrix,dtype="f")
        index_matrix=np.swapaxes(index_matrix,0,2).copy()
        end=time.time()
        print(end-start,'s')
        return index_matrix
    
    def generating_label_image(index_matrix):
        start=time.time()
        print ("generating main branch")
        index_matrix=airway_modeling(index_matrix,trachea_i,trachea,lm,rm,2100)
        index_matrix=airway_modeling(index_matrix,rm_i,rm,ru,br,400)
        index_matrix=airway_modeling(index_matrix,ru_i,ru,r1,r2,2000)
        index_matrix=airway_modeling(index_matrix,br_i,br,r45,r6,500)
        index_matrix=airway_modeling(index_matrix,r45_i,r45,r4,r5,1900)
        index_matrix=airway_modeling(index_matrix,r6_i,r6,rl7,rl7,600)
        index_matrix=airway_modeling(index_matrix,rl7_i,rl7,r7,rl,1800)
        index_matrix=airway_modeling(index_matrix,rl_i,rl,r910,r910,700)
        index_matrix=airway_modeling(index_matrix,r910_i,r910,r9,r10,1700)
        index_matrix=airway_modeling(index_matrix,r8_i,r8,sr8[0],sr8[1],800)
        index_matrix=airway_modeling(index_matrix,r9_i,r9,sr9[0],sr9[1],1600)
        index_matrix=airway_modeling(index_matrix,r10_i,r10,sr10[0],sr10[1],900)
        index_matrix=airway_modeling(index_matrix,r4_i,r4,sr4[0],sr4[1],1500)
        index_matrix=airway_modeling(index_matrix,r5_i,r5,sr5[0],sr5[1],1000)
        index_matrix=airway_modeling(index_matrix,r7_i,r7,sr7[0],sr7[1],1400)
        index_matrix=airway_modeling(index_matrix,r1_i,r1,sr1[0],sr1[1],1100)
        index_matrix=airway_modeling(index_matrix,r2_i,r2,sr2[0],sr2[1],1300)
        index_matrix=airway_modeling(index_matrix,r3_i,r3,sr3[0],sr3[1],1200)
        index_matrix=airway_modeling(index_matrix,lm_i,lm,lu,ll6,350)
        index_matrix=airway_modeling(index_matrix,lu_i,lu,l123,ll6,2150)
        index_matrix=airway_modeling(index_matrix,ll6_i,ll6,l6,ll,450)
        index_matrix=airway_modeling(index_matrix,l6_i,l6,sl6[0],sl6[1],2050)
        index_matrix=airway_modeling(index_matrix,ll_i,ll,l910,l8,550)
        index_matrix=airway_modeling(index_matrix,l8_i,l8,sl8[0],sl8[1],1950)
        index_matrix=airway_modeling(index_matrix,l910_i,l910,l9,l10,650)
        index_matrix=airway_modeling(index_matrix,l123_i,l123,l12,l3,1850)
        index_matrix=airway_modeling(index_matrix,l12_i,l12,l1,l2,750)
        index_matrix=airway_modeling(index_matrix,l1_i,l1,sl1[0],sl1[1],1750)
        index_matrix=airway_modeling(index_matrix,l2_i,l2,sl2[0],sl2[1],850)
        index_matrix=airway_modeling(index_matrix,l3_i,l3,sl3[0],sl3[1],1650)
        index_matrix=airway_modeling(index_matrix,l45_i,l45,l4,l5,950)
        index_matrix=airway_modeling(index_matrix,l4_i,l4,sl4[0],sl4[1],1550)
        index_matrix=airway_modeling(index_matrix,l5_i,l5,sl5[0],sl5[1],1050)
        index_matrix=airway_modeling(index_matrix,l9_i,l9,sl9[0],sl9[1],1450)
        index_matrix=airway_modeling(index_matrix,l10_i,l10,sl10[0],sl10[1],1150)

        print ("generating son branch")
        index_matrix=s_airway_modeling(index_matrix,sr1)
        index_matrix=s_airway_modeling(index_matrix,sr2)
        index_matrix=s_airway_modeling(index_matrix,sr3)
        index_matrix=s_airway_modeling(index_matrix,sr4)
        index_matrix=s_airway_modeling(index_matrix,sr5)
        index_matrix=s_airway_modeling(index_matrix,sr6)
        index_matrix=s_airway_modeling(index_matrix,sr7)
        index_matrix=s_airway_modeling(index_matrix,sr8)
        index_matrix=s_airway_modeling(index_matrix,sr9)
        index_matrix=s_airway_modeling(index_matrix,sr10)
        index_matrix=s_airway_modeling(index_matrix,sl1)
        index_matrix=s_airway_modeling(index_matrix,sl2)
        index_matrix=s_airway_modeling(index_matrix,sl3)
        index_matrix=s_airway_modeling(index_matrix,sl4)
        index_matrix=s_airway_modeling(index_matrix,sl5)
        index_matrix=s_airway_modeling(index_matrix,sl6)
        index_matrix=s_airway_modeling(index_matrix,sl8)
        index_matrix=s_airway_modeling(index_matrix,sl9)
        index_matrix=s_airway_modeling(index_matrix,sl10)

        print("generating grandson branch")
        index_matrix=ss_airway_modeling(index_matrix,ssr1)
        index_matrix=ss_airway_modeling(index_matrix,ssr2)
        index_matrix=ss_airway_modeling(index_matrix,ssr3)
        index_matrix=ss_airway_modeling(index_matrix,ssr4)
        index_matrix=ss_airway_modeling(index_matrix,ssr5)
        index_matrix=ss_airway_modeling(index_matrix,ssr6)
        index_matrix=ss_airway_modeling(index_matrix,ssr7)
        index_matrix=ss_airway_modeling(index_matrix,ssr8)
        index_matrix=ss_airway_modeling(index_matrix,ssr9)
        index_matrix=ss_airway_modeling(index_matrix,ssr10)
        index_matrix=ss_airway_modeling(index_matrix,ssl1)
        index_matrix=ss_airway_modeling(index_matrix,ssl2)
        index_matrix=ss_airway_modeling(index_matrix,ssl3)
        index_matrix=ss_airway_modeling(index_matrix,ssl4)
        index_matrix=ss_airway_modeling(index_matrix,ssl5)
        index_matrix=ss_airway_modeling(index_matrix,ssl6)
        index_matrix=ss_airway_modeling(index_matrix,ssl8)
        index_matrix=ss_airway_modeling(index_matrix,ssl9)
        index_matrix=ss_airway_modeling(index_matrix,ssl10)
        print ("swaping axes")
        index_matrix=np.array(index_matrix,dtype="f")
        index_matrix=np.swapaxes(index_matrix,0,2).copy()
        end=time.time()
        print(end-start,'s')
        return index_matrix
    
    def image_test_generation(index_matrix):
        index_matrix=generating_test_image(index_matrix)
        print (np.amax(index_matrix))
        print ("generating test Image")
        image=itk.GetImageFromArray(index_matrix)
        image.SetSpacing([0.5,0.5,0.5])
        return image

    def image_label_generation(index_matrix):
        index_matrix=generating_label_image(index_matrix)
        print (np.amax(index_matrix))
        image=itk.GetImageFromArray(index_matrix)
        image.SetSpacing([0.5,0.5,0.5])
        return image
    def flip_image(image):
        PixelType=itk.F
        ImageType=itk.Image[PixelType,3]
        flipAxes=(False,False,True)

        flipfilter=itk.FlipImageFilter[ImageType].New()
        flipfilter.SetInput(image)
        flipfilter.SetFlipAxes(flipAxes)
        flipfilter.Update()
        return flipfilter.GetOutput()
    image_l=flip_image(image_label_generation(np.zeros((720,720,768))))
    image_t=flip_image(image_test_generation(np.zeros((720,720,768))))

    subjectid='{num:04d}'.format(num=num_id)
    ImageType = itk.Image[itk.F, 3]
    WriterType = itk.ImageFileWriter[ImageType]
    writer = WriterType.New()
    writer.SetFileName('labeled/'+subjectid+'labled.nii.gz')
    writer.SetInput(image_l)
    writer.Update()
    writer.SetFileName('test/'+subjectid+'origin.nii.gz')
    writer.SetInput(image_t)
    writer.Update()
    print ('imageset'+subjectid+'complete')

# %%
image=test_ge(1)

# %% [markdown]
# ## registration

# %%
# from __future__ import print_function

# import SimpleITK as sitk
# import sys
# import os


# def command_iteration(method, bspline_transform) :
#     if method.GetOptimizerIteration() == 0:
#         # The BSpline is resized before the first optimizer
#         # iteration is completed per level. Print the transform object
#         # to show the adapted BSpline transform.
#         print(bspline_transform)


#     print("{0:3} = {1:10.5f}".format(method.GetOptimizerIteration(),
#                                      method.GetMetricValue()))



# def command_multi_iteration(method) :
#     # The sitkMultiResolutionIterationEvent occurs before the
#     # resolution of the transform. This event is used here to print
#     # the status of the optimizer from the previous registration level.
#     if R.GetCurrentLevel() > 0:
#         print("Optimizer stop condition: {0}".format(R.GetOptimizerStopConditionDescription()))
#         print(" Iteration: {0}".format(R.GetOptimizerIteration()))
#         print(" Metric value: {0}".format(R.GetMetricValue()))

#     print("--------- Resolution Changing ---------")


# if len ( sys.argv ) < 4:
#     print( "Usage: {0} <fixedImageFilter> <movingImageFile> <outputTransformFile>".format(sys.argv[0]))
#     sys.exit ( 1 )


# fixed = sitk.ReadImage(sys.argv[1], sitk.sitkFloat32)

# moving = sitk.ReadImage(sys.argv[2], sitk.sitkFloat32)

# transformDomainMeshSize=[2]*fixed.GetDimension()
# tx = sitk.BSplineTransformInitializer(fixed,
#                                       transformDomainMeshSize )

# print("Initial Number of Parameters: {0}".format(tx.GetNumberOfParameters()))

# R = sitk.ImageRegistrationMethod()
# R.SetMetricAsJointHistogramMutualInformation()

# R.SetOptimizerAsGradientDescentLineSearch(5.0,
#                                           100,
#                                           convergenceMinimumValue=1e-4,
#                                           convergenceWindowSize=5)

# R.SetInterpolator(sitk.sitkLinear)

# R.SetInitialTransformAsBSpline(tx,
#                                inPlace=True,
#                                scaleFactors=[1,2,5])
# R.SetShrinkFactorsPerLevel([4,2,1])
# R.SetSmoothingSigmasPerLevel([4,2,1])

# R.AddCommand( sitk.sitkIterationEvent, lambda: command_iteration(R, tx) )
# R.AddCommand( sitk.sitkMultiResolutionIterationEvent, lambda: command_multi_iteration(R) )

# outTx = R.Execute(fixed, moving)

# print("-------")
# print(tx)
# print(outTx)
# print("Optimizer stop condition: {0}".format(R.GetOptimizerStopConditionDescription()))
# print(" Iteration: {0}".format(R.GetOptimizerIteration()))
# print(" Metric value: {0}".format(R.GetMetricValue()))

# sitk.WriteTransform(outTx,  sys.argv[3])

# if ( not "SITK_NOSHOW" in os.environ ):

#     resampler = sitk.ResampleImageFilter()
#     resampler.SetReferenceImage(fixed);
#     resampler.SetInterpolator(sitk.sitkLinear)
#     resampler.SetDefaultPixelValue(100)
#     resampler.SetTransform(outTx)

#     out = resampler.Execute(moving)
#     simg1 = sitk.Cast(sitk.RescaleIntensity(fixed), sitk.sitkUInt8)
#     simg2 = sitk.Cast(sitk.RescaleIntensity(out), sitk.sitkUInt8)
#     cimg = sitk.Compose(simg1, simg2, simg1//2.+simg2//2.)
#     sitk.Show( cimg, "Image Registration Composition" )

# %%
#Input
fixedfilename="test/0001origin.nii.gz"
movingfilename="moving_img/ZUNU_vida-airtree.img.gz"
print ("fixed image file",fixedfilename)
print ("moving image file",movingfilename)
Dimension=3
PixelType=itk.F
ImageType=itk.Image[PixelType,3]
freader=itk.ImageFileReader[ImageType].New()
freader.SetFileName(fixedfilename)
freader.Update()
fimage=freader.GetOutput()
mreader=itk.ImageFileReader[ImageType].New()
mreader.SetFileName(movingfilename)
mreader.Update()
mimage=mreader.GetOutput()
# Out:
# fixed image file test/0001origin.nii.gz
# moving image file moving_img/ZUNU_vida-airtree.img.gz

# %%
# Set Metric And Transform Type
TransformType=itk.BSplineTransform[itk.D,3,3]
btransform=TransformType.New()
optimizer=itk.RegularStepGradientDescentOptimizerv4[itk.D].New()
metric=itk.MeanSquaresImageToImageMetricv4[ImageType,ImageType].New()
RegistrationType=itk.ImageRegistrationMethodv4[ImageType,ImageType]
registration=RegistrationType.New()
registration.SetMetric(metric)
registration.SetOptimizer(optimizer)
interpolator=itk.LinearInterpolateImageFunction[ImageType,itk.D].New()
metric.SetFixedInterpolator(interpolator)
metric.SetMovingInterpolator(interpolator)
fspacing=fimage.GetSpacing()
forigin=fimage.GetOrigin()
fregion=fimage.GetLargestPossibleRegion()
fsize=fregion.GetSize()
fsz=np.array(fsize)
def get_center(origin,size,spacing):
    center=np.zeros(3)
    for i in range (3):
        center[i]=np.array(origin)[i]+np.array(spacing)[i]*np.array(size)[i]
    return center
fcenter=get_center(forigin,fsz,fspacing)
mspacing=mimage.GetSpacing()
morigin=mimage.GetOrigin()
mregion=mimage.GetLargestPossibleRegion()
msize=mregion.GetSize()
msz=np.array(msize)
mcenter=get_center(morigin,msz,mspacing)
initialtransformtype1=itk.VersorRigid3DTransform[itk.D].New()
initializer=itk.CenteredTransformInitializer[initialtransformtype1,fimage,mimage].New()
registration.SetInitialTransform(initializer)
registration.SetNumberOfLevels(3)
registration.SetShrinkFactorsPerLevel([4,2,1])
registration.SetSmoothingSigmasPerLevel([4,2,1])
registration.SetFixedImage(fimage)
registration.SetMovingImage(mimage)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-2186c8e0fd58> in <module>
#      30 initialtransformtype1=itk.VersorRigid3DTransform[itk.D].New()
#      31 initializer=itk.CenteredTransformInitializer[initialtransformtype1,fimage,mimage].New()
# ---> 32 registration.SetInitialTransform(initializer)
#      33 registration.SetNumberOfLevels(3)
#      34 registration.SetShrinkFactorsPerLevel([4,2,1])
#
# TypeError: in method 'itkImageRegistrationMethodv4REGv4F3F3_SetInitialTransform', argument 2 of type 'itkTransformD33 const *'

# %%
itk.CenteredTransformInitializer.GetTypes()
# Out:
# <itkTemplate itk::CenteredTransformInitializer>
# Options:
#   [<class 'itkCenteredRigid2DTransformPython.itkCenteredRigid2DTransformD'>, <class 'itkImagePython.itkImageF2'>, <class 'itkImagePython.itkImageF2'>]
#   [<class 'itkCenteredRigid2DTransformPython.itkCenteredRigid2DTransformD'>, <class 'itkImagePython.itkImageSS2'>, <class 'itkImagePython.itkImageSS2'>]
#   [<class 'itkCenteredRigid2DTransformPython.itkCenteredRigid2DTransformD'>, <class 'itkImagePython.itkImageUC2'>, <class 'itkImagePython.itkImageUC2'>]
#   [<class 'itkCenteredRigid2DTransformPython.itkCenteredRigid2DTransformD'>, <class 'itkImagePython.itkImageUS2'>, <class 'itkImagePython.itkImageUS2'>]
#   [<class 'itkVersorRigid3DTransformPython.itkVersorRigid3DTransformD'>, <class 'itkImagePython.itkImageF3'>, <class 'itkImagePython.itkImageF3'>]
#   [<class 'itkVersorRigid3DTransformPython.itkVersorRigid3DTransformD'>, <class 'itkImagePython.itkImageSS3'>, <class 'itkImagePython.itkImageSS3'>]
#   [<class 'itkVersorRigid3DTransformPython.itkVersorRigid3DTransformD'>, <class 'itkImagePython.itkImageUC3'>, <class 'itkImagePython.itkImageUC3'>]
#   [<class 'itkVersorRigid3DTransformPython.itkVersorRigid3DTransformD'>, <class 'itkImagePython.itkImageUS3'>, <class 'itkImagePython.itkImageUS3'>]

# %%
fimage.GetOrigin()
# Out:
# itkPointD3 ([0, 0, -383.5])

# %%
itk.
